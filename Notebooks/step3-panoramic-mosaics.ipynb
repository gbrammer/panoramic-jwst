# %% [markdown]
# # Define PANORAMIC fields
#
# The associations have been computed in `step1-define-associations.ipynb` and the preprocessing executed elsewhere....

# %%
import os
os.chdir('../Mosaics')

# %%
! head -1 panoramic_fields.txt
! cat panoramic_fields.txt | sort -k 9
# Out:
# # field        n   sx    sy   ra         dec         nx  ny  date       time
# j170720p5853 120   4.9   6.9 256.841500   58.879350  4   6  2023-02-18 00:03:56.209
# j153500p2325 240   3.6   6.4 233.742500   23.420000  3   5  2023-03-06 09:39:23.999
# j145652p2444  40   5.3   6.7 224.223500   24.740000  4   5  2023-03-24 02:33:18.312
# j123800p6217 432  17.0  15.7 189.485500   62.249400 13  12  2023-03-28 07:25:57.468
# j125652p5652 240   6.4   3.8 194.211500   56.865700  5   3  2023-04-01 19:15:23.999
# j090000p0207  80   4.0   6.5 135.004000    2.114070  3   5  2023-04-03 09:42:05.050
# j150604p5409 160   6.5   7.1 226.514500   54.154800  5   6  2023-04-03 14:28:49.893
# j093452p6116  80   5.9   6.5 143.708500   61.272400  5   5  2023-04-06 19:16:17.682
# j094232p0923 120   4.9   6.7 145.630000    9.378995  4   5  2023-04-19 09:41:11.366
# j093144p0819 120   4.7   6.7 142.941000    8.325030  4   5  2023-04-20 04:53:11.366
# j100736p2109  60   5.2   6.7 151.906000   21.155250  4   5  2023-05-07 07:21:18.312
# j134348p5549 120   6.2   6.3 205.941500   55.819400  5   5  2023-06-10 07:16:17.682
# j131432p2432 120   5.8   6.6 198.635000   24.529750  5   5  2023-06-11 14:27:56.209
# j121932p0330 120   5.3   6.7 184.880000    3.497880  4   5  2023-06-13 00:04:17.682
# j142536p5630 120   6.1   6.5 216.404500   56.507500  5   5  2023-06-24 14:33:18.312
# j130016p1215  60   5.4   6.7 195.065000   12.249050  4   5  2023-06-25 12:08:46.102
# j141932p5254  70   6.1   6.4 214.885000   52.892150  5   5  2023-06-28 05:01:57.468
# j144904m1017 120   5.0   6.7 222.271000  -10.283300  4   5  2023-07-02 16:53:11.366
# j123140m1618 120   5.2   6.7 187.911500  -16.305450  4   5  2023-07-02 19:15:56.209
# j000352m1120 120   4.9   6.7   0.960429  -11.326800  4   5  2023-07-14 02:29:11.366
# j224616m0531 430   5.3   6.8 341.565000   -5.519550  4   5  2023-07-16 16:54:58.734
# j224604m0518 180   5.6   7.8 341.515500   -5.304580  5   6  2023-07-17 14:36:10.100
# j021824m0517  70   4.6   6.7  34.598750   -5.278195  4   5  2023-07-23 07:25:57.468
# j043844m6849  60   6.0   6.5  69.682700  -68.821450  5   5  2023-07-25 02:35:05.680
# j234512m4235  80   4.6   6.6 356.304500  -42.590600  4   5  2023-07-28 05:00:10.100
# j010408m5508 120   4.5   6.7  16.039400  -55.141650  4   5  2023-08-05 09:39:56.209
# j021728m0214 240   4.7   6.7  34.363000   -2.228235  4   5  2023-08-06 21:43:52.418
# j013444m1532 120   4.0   6.6  23.687100  -15.531200  3   5  2023-08-14 00:03:56.209
# j010500p0217 200   5.2   7.0  16.245050    2.282490  4   6  2023-08-18 02:50:29.040
# j021744m0518 278  15.0  12.2  34.410200   -5.308470 11   9  2023-08-20 09:49:57.468
# j041624m2411  90   5.0   7.1  64.103750  -24.179150  4   6  2023-08-22 17:02:40.415
# j041616m2409 240   4.2   6.7  64.061150  -24.144900  4   5  2023-08-27 05:14:29.040
# # field        n   sx    sy   ra         dec         nx  ny  date       time

# %%
# Which mosaics hae been made?
! cat mosaic_log.txt
# Out:
# # field  version date time
# j090000p0207  v6.0  2023-05-04 09:44:57.191
# j145652p2444  v6.0  2023-05-04 10:37:56.604
# j093144p0819  v6.0  2023-05-04 11:16:46.528
# j100736p2109  v6.0  2023-05-10 16:07:03.162
# j093452p6116  v6.0  2023-05-10 18:43:31.732
# j125652p5652  v6.0  2023-05-10 18:44:39.470
# j150604p5409  v6.0  2023-05-10 19:45:12.123
# j170720p5853  v6.0  2023-05-10 20:00:33.283
# j094232p0923  v6.0  2023-05-10 20:12:52.988
# j153500p2325  v6.0  2023-05-10 22:13:33.482
# j131432p2432  v6.0  2023-06-13 13:57:40.377
# j134348p5549  v6.0  2023-06-13 14:20:56.488
# j121932p0330  v6.0  2023-06-14 13:06:03.030
# j142536p5630  v6.0  2023-06-29 19:20:17.000
# j130016p1215  v6.0  2023-06-29 20:56:29.000
# j144904m1017  v6.0  2023-07-04 17:49:08.950
# j123140m1618  v6.0  2023-07-04 18:35:28.420
# j000352m1120  v6.0  2023-07-19 21:19:40.026
# j043844m6849  v6.0  2023-08-01 17:44:07.158
# j021824m0517  v6.0  2023-08-01 18:12:07.183
# j234512m4235  v6.0  2023-08-01 21:22:38.265
# j010408m5508  v6.0  2023-08-07 22:03:14.504
# j021728m0214  v6.0  2023-08-07 22:38:49.899
# j224612m0527  v6.0  2023-08-10 19:29:25.273
# j224604m0518  v6.0  2023-08-12 17:20:14.846
# j224616m0531  v6.0  2023-08-12 20:37:07.216
# j013444m1532  v6.0  2023-08-15 09:45:42.016
# j010500p0217  v6.0  2023-08-31 07:46:09.341
# j021744m0518  v6.0  2023-09-04 15:50:23.074
# j014428p1715  v7.0  2023-09-05 21:58:07.841
# j033236m2755  v7.0  2023-09-06 01:12:35.951
# j024000m0142  v7.0  2023-09-06 12:48:49.759
# j013900m1019  v7.0  2023-09-08 15:16:48.484
# j041624m2411  v7.0  2023-09-11 16:28:49.134
# j041616m2409  v7.0  2023-09-11 16:58:32.420

# %%
import os
import gc
import glob

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt

import astropy.io.fits as pyfits
import astropy.wcs as pywcs
import astropy.time

from grizli.aws import db, visit_processor
from grizli import utils, prep
from grizli.pipeline import auto_script

from mastquery import overlaps
# Out:
# Set ROOT_PATH=/usr/local/share/python/panoramic-jwst/Mosaics

# %%
def create_s3_index(path, output_file="index.html", extra_html="", upload=True):
    """
    Create HTML listing of an S3 path
    """
    import time

    url = path.replace('s3://', 'https://s3.amazonaws.com/')

    lsfile = output_file.replace('.html','.ls')

    # Sort by filename
    sort_str = 'sort -k 4'

    os.system(f'aws s3 ls {path} | {sort_str} |grep -v PRE |grep -v {output_file} > {lsfile}')

    now = time.ctime()
    html=f"<h3>{now}</h3>\n"

    html += extra_html

    html += "\n<pre>\n"
    
    lines=open(lsfile).readlines()
    for line in lines:
        lsp = line.split()
        if len(lsp) == 4:
            html += "{0} {1} {2:>10} <a href={4}{3} > {3} </a>\n".format(*lsp, url)

    html += '</pre>\n'
    fp = open(output_file,'w')
    fp.write(html)
    fp.close()
    
    if upload:
        os.system(f'aws s3 cp {output_file} {path} --acl public-read')
        print(path.replace('s3://', 'https://s3.amazonaws.com/') + output_file)

    print(output_file)

# %% [markdown]
# ## Query database for exposure footprints

# %%
# Query the grizli database for processed exposures
program_id = 2514 # Panoramic

res = db.SQL(f"""select assoc, dataset, filter,
crval1 as ra, crval2 as dec, footprint as coords,
expstart as t_min, exptime, detector, instrume
from exposure_files where (dataset like 'jw{program_id:05d}%%')
""")

len(res)
# Out:
# 5365

# %%
# Compute general footprint for a given field based on NIRCam overlaps
if 0:
    # e.g., MACS0416
    
    ra, dec = 93.968, -57.781

    res = db.SQL(f"""select assoc, dataset, filter,
crval1 as ra, crval2 as dec, footprint as coords,
expstart as t_min, exptime, detector, instrume
from exposure_files where polygon(footprint) && polygon(circle(point({ra}, {dec}),0.5)) and instrume = 'NIRCAM'
""")
    
    res['parent'] = [a.split('_')[0] for a in res['assoc']]
    un = utils.Unique(res['parent'])
    res['parent'] = un.values[np.argmax(un.counts)]
    un = utils.Unique(res['parent'])

# %%
# Group by "parent" defined when associations were generated
res['parent'] = [a.split('_')[0] for a in res['assoc']]
res['parent-filt'] = [a.split('_')[0] + '-' + f
                      for a, f in zip(res['assoc'], res['filter'])]
       
# Split double field j224612m0527
test = res['parent'] == 'j224612m0527'
south = (res['dec'] < -5.4)
print((test & south).sum(), (test & ~south).sum())

parent = res['parent'].tolist()

for i in np.where(test & south)[0]:
    parent[i]= utils.radec_to_targname(res['ra'][test & south].mean(), res['dec'][test & south].mean())
for i in np.where(test & ~south)[0]:
    parent[i]= utils.radec_to_targname(res['ra'][test & ~south].mean(), res['dec'][test & ~south].mean())
    
res['parent'] = parent

# Merge MACS0416
dr = np.sqrt((res['ra']-64.061150)**2 +  (res['dec'] + 24.144900)**2)
macs0416 = dr < 0.4
if macs0416.sum() >  0:
    print(f"Merge {np.unique(res['parent'][macs0416]).tolist()} > 'j041616m2409'")
    res['parent'][macs0416] = 'j041616m2409'
    
un = utils.Unique(res['parent'])
# Out:
# 430 180
# Merge ['j041616m2409', 'j041624m2411'] > 'j041616m2409'
#    N  value
# ====  ==========
#    9  j123816p6217
#   40  j145652p2444
#   60  j100736p2109
#   60  j130016p1215
#   60  j043844m6849
#   70  j141932p5254
#   70  j021824m0517
#   80  j093452p6116
#   80  j090000p0207
#   80  j234512m4235
#   90  j024000m0142
#  120  j000352m1120
#  120  j170720p5853
#  120  j010408m5508
#  120  j144904m1017
#  120  j093144p0819
#  120  j142536p5630
#  120  j094232p0923
#  120  j134348p5549
#  120  j121932p0330
#  120  j123140m1618
#  120  j131432p2432
#  120  j013444m1532
#  142  j033236m2755
#  160  j150604p5409
#  172  j013900m1019
#  180  j014428p1715
#  180  j224604m0518
#  200  j010500p0217
#  240  j021728m0214
#  240  j153500p2325
#  240  j125652p5652
#  280  j021744m0518
#  330  j041616m2409
#  430  j224616m0531
#  432  j123800p6217

# %%
! rm panoramic_fields.txt

# %%
row = '# field        n   sx    sy   ra         dec         nx  ny  date       time'
with open('panoramic_fields.txt','w') as fp:
    fp.write(row+'\n')

print(row)

for field in un.values:
    rf = res[un[field]]
    
    # Things needed for the plot script
    rf.meta['NAME'] = field
    rf.meta['RA'] = np.mean(rf['ra'])
    rf.meta['DEC'] = np.mean(rf['dec'])
    rf.meta['MW_EBV'] = 0.0
    
    rf['obs_id'] = rf['dataset']
    rf['proposal_id'] = [int(d[3:7]) for d in rf['dataset']]
    rf['t_max'] = rf['t_min'] + rf['exptime']/86400.
    rf['instrument_name'] = rf['instrume']
    rf['target'] = 'indef'
    rf['filter'] = [f.split('-')[0] for f in rf['filter']]
    rf['footprint'] = [f'POLYGON {f.replace("(","").replace(")","").replace(","," ")}'
                       for f in rf['coords']]

    _ = overlaps.split_associations(rf, assoc_min=0, 
                                        #assoc_args=assoc_args,
                                        force_split=True,
                                        with_ls_thumbnail=False,
                                        xsize=6,
                                        )
                                        #ls_args=LS_ARGS)
    
    tab = _[0]
    fig = _[1]
    fig.savefig(f'panoramic-{field}.png')
    
    # size: the plot window is a box containing the exposures padded by 1arcmin
    cosd = np.cos(rf.meta['DEC']/180*np.pi)
    sx = (rf.meta['XMAX'] - rf.meta['XMIN'])*cosd*60-1
    sy = (rf.meta['YMAX'] - rf.meta['YMIN'])*60-1
    
    # Center of the plot as center ra/dec
    ra0 = (rf.meta['XMAX'] + rf.meta['XMIN'])/2.
    de0 = (rf.meta['YMAX'] + rf.meta['YMIN'])/2.
    
    # Size in units of 2048 x 40mas/pixel 
    nx = int(np.ceil(sx/(2048*0.04/60)))
    ny = int(np.ceil(sy/(2048*0.04/60)))

    tmax = astropy.time.Time(rf['t_max'].max(), format='mjd').iso

    row = f"{field:12} {un[field].sum():>3} {sx:5.1f} {sy:5.1f} {ra0:10.6f}  {de0:10.6f} {nx:>2}  {ny:>2}  {tmax}"
    if 1:
        with open('panoramic_fields.txt','a') as fp:
            fp.write(row+'\n')

    print(row)
# Out:
# # field        n   sx    sy   ra         dec         nx  ny  date       time
# j000352m1120 120   4.9   6.7   0.960429  -11.326800  4   5  2023-07-14 02:29:11.366
# j010408m5508 120   4.5   6.7  16.039400  -55.141650  4   5  2023-08-05 09:39:56.209
# j010500p0217 200   5.2   7.0  16.245050    2.282490  4   6  2023-08-18 02:50:29.040
# j013444m1532 120   4.0   6.6  23.687100  -15.531200  3   5  2023-08-14 00:03:56.209
# j013900m1019 172   4.9   7.9  24.743100  -10.320000  4   6  2023-08-23 09:52:27.783
# j014428p1715 180   5.5   7.8  26.108450   17.240550  5   6  2023-08-29 19:27:44.836
# j021728m0214 240   4.7   6.7  34.363000   -2.228235  4   5  2023-08-06 21:43:52.418
# j021744m0518 280  15.0  12.2  34.410200   -5.308470 11   9  2023-08-20 09:49:57.468
# j021824m0517  70   4.6   6.7  34.598750   -5.278195  4   5  2023-07-23 07:25:57.468
# j024000m0142  90   3.8   6.9  40.007250   -1.691670  3   6  2023-09-05 05:02:40.415
# j033236m2755 142   3.6   6.3  53.156800  -27.912200  3   5  2023-09-03 06:19:37.230
# j041616m2409 330   6.9   9.0  64.086300  -24.164050  6   7  2023-08-27 05:14:29.040
# j043844m6849  60   6.0   6.5  69.682700  -68.821450  5   5  2023-07-25 02:35:05.680
# j090000p0207  80   4.0   6.5 135.004000    2.114070  3   5  2023-04-03 09:42:05.050
# j093144p0819 120   4.7   6.7 142.941000    8.325030  4   5  2023-04-20 04:53:11.366
# j093452p6116  80   5.9   6.5 143.708500   61.272400  5   5  2023-04-06 19:16:17.682
# j094232p0923 120   4.9   6.7 145.630000    9.378995  4   5  2023-04-19 09:41:11.366
# j100736p2109  60   5.2   6.7 151.906000   21.155250  4   5  2023-05-07 07:21:18.312
# j121932p0330 120   5.3   6.7 184.880000    3.497880  4   5  2023-06-13 00:04:17.682
# j123140m1618 120   5.2   6.7 187.911500  -16.305450  4   5  2023-07-02 19:15:56.209
# j123800p6217 432  17.0  15.7 189.485500   62.249400 13  12  2023-03-28 07:25:57.468
# j123816p6217   9   6.3   3.7 189.570000   62.278450  5   3  2023-03-26 02:37:57.468
# j125652p5652 240   6.4   3.8 194.211500   56.865700  5   3  2023-04-01 19:15:23.999
# j130016p1215  60   5.4   6.7 195.065000   12.249050  4   5  2023-06-25 12:08:46.102
# j131432p2432 120   5.8   6.6 198.635000   24.529750  5   5  2023-06-11 14:27:56.209
# j134348p5549 120   6.2   6.3 205.941500   55.819400  5   5  2023-06-10 07:16:17.682
# j141932p5254  70   6.1   6.4 214.885000   52.892150  5   5  2023-06-28 05:01:57.468
# j142536p5630 120   6.1   6.5 216.404500   56.507500  5   5  2023-06-24 14:33:18.312
# j144904m1017 120   5.0   6.7 222.271000  -10.283300  4   5  2023-07-02 16:53:11.366
# j145652p2444  40   5.3   6.7 224.223500   24.740000  4   5  2023-03-24 02:33:18.312
# j150604p5409 160   6.5   7.1 226.514500   54.154800  5   6  2023-04-03 14:28:49.893
# j153500p2325 240   3.6   6.4 233.742500   23.420000  3   5  2023-03-06 09:39:23.999
# j170720p5853 120   4.9   6.9 256.841500   58.879350  4   6  2023-02-18 00:03:56.209
# j224604m0518 180   5.6   7.8 341.515500   -5.304580  5   6  2023-07-17 14:36:10.100
# j224616m0531 430   5.3   6.8 341.565000   -5.519550  4   5  2023-07-16 16:54:58.734
# j234512m4235  80   4.6   6.6 356.304500  -42.590600  4   5  2023-07-28 05:00:10.100

# %% [markdown]
# ## Run mosaics, catalogs

# %%
# Set version

mosaic_version = 'v6.0' # latest grizli (May 2023)

# %%
os.path.exists('/workspaces/panoramic-jwst')
# Out:
# True

# %%
# Work in /scratch on the root filesystem if expect to make more than 5 GB of files.
# NB: files here won't be saved when the machine is shut down!

# hmm, but doesn't seem to work
if 0:
    work_path = '/scratch'
    if not os.path.exists(work_path):
        os.makedirs(work_path)
elif os.path.exists('/workspaces/panoramic-jwst'):
    work_path = '/workspaces/panoramic-jwst/Mosaics'
else:
    work_path = '/work'

os.chdir(work_path)
print(f'Working directory: {work_path}')

! df -h .
# Out:
# Working directory: /workspaces/panoramic-jwst/Mosaics
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop3       32G   16G   14G  54% /workspaces

# %%
fields = utils.read_catalog('panoramic_fields.txt')
so = np.argsort(fields['date'])

fields[so].to_pandas()
# Out:
#            field    n    sx    sy          ra        dec  nx  ny        date  \
# 0   j170720p5853  120   4.9   6.9  256.841500  58.879350   4   6  2023-02-18
# 1   j153500p2325  240   3.6   6.4  233.742500  23.420000   3   5  2023-03-06
# 2   j145652p2444   40   5.3   6.7  224.223500  24.740000   4   5  2023-03-24
# 3   j123800p6217  432  17.0  15.7  189.485500  62.249400  13  12  2023-03-28
# 4   j125652p5652  240   6.4   3.8  194.211500  56.865700   5   3  2023-04-01
# 5   j150604p5409  160   6.5   7.1  226.514500  54.154800   5   6  2023-04-03
# 6   j090000p0207   80   4.0   6.5  135.004000   2.114070   3   5  2023-04-03
# 7   j093452p6116   80   5.9   6.5  143.708500  61.272400   5   5  2023-04-06
# 8   j094232p0923  120   4.9   6.7  145.630000   9.378995   4   5  2023-04-19
# 9   j093144p0819  120   4.7   6.7  142.941000   8.325030   4   5  2023-04-20
# 10  j100736p2109   60   5.2   6.7  151.906000  21.155250   4   5  2023-05-07
# 11  j134348p5549  120   6.2   6.3  205.941500  55.819400   5   5  2023-06-10
# 12  j131432p2432  120   5.8   6.6  198.635000  24.529750   5   5  2023-06-11
# 13  j121932p0330  120   5.3   6.7  184.880000   3.497880   4   5  2023-06-13
# 14  j142536p5630  120   6.1   6.5  216.404500  56.507500   5   5  2023-06-24
# 15  j130016p1215   60   5.4   6.7  195.065000  12.249050   4   5  2023-06-25
# 16  j141932p5254   70   6.1   6.4  214.885000  52.892150   5   5  2023-06-28
# 17  j123140m1618  120   5.2   6.7  187.911500 -16.305450   4   5  2023-07-02
# 18  j144904m1017  120   5.0   6.7  222.271000 -10.283300   4   5  2023-07-02
# 19  j000352m1120  120   4.9   6.7    0.960429 -11.326800   4   5  2023-07-14
# 20  j224612m0527  610   8.4  20.2  341.539000  -5.407955   7  15  2023-07-17
# 21  j021824m0517   70   4.6   6.7   34.598750  -5.278195   4   5  2023-07-23
# 22  j043844m6849   60   6.0   6.5   69.682700 -68.821450   5   5  2023-07-25
# 23  j234512m4235   80   4.6   6.6  356.304500 -42.590600   4   5  2023-07-28
# 24  j010408m5508  120   4.5   6.7   16.039400 -55.141650   4   5  2023-08-05
# 25  j021728m0214  240   4.7   6.7   34.363000  -2.228235   4   5  2023-08-06
# 26  j013444m1532  120   4.0   6.6   23.687100 -15.531200   3   5  2023-08-14
#
#             time
# 0   00:03:56.209
# 1   09:39:23.999
# 2   02:33:18.312
# 3   07:25:57.468
# 4   19:15:23.999
# 5   14:28:49.893
# 6   09:42:05.050
# 7   19:16:17.682
# 8   09:41:11.366
# 9   04:53:11.366
# 10  07:21:18.312
# 11  07:16:17.682
# 12  14:27:56.209
# 13  00:04:17.682
# 14  14:33:18.312
# 15  12:08:46.102
# 16  05:01:57.468
# 17  19:15:56.209
# 18  16:53:11.366
# 19  02:29:11.366
# 20  14:36:10.100
# 21  07:25:57.468
# 22  02:35:05.680
# 23  05:00:10.100
# 24  09:39:56.209
# 25  21:43:52.418
# 26  00:03:56.209

# %%
field_to_run = 'j013444m1532'

# %%
# Make a mosaic

LW_FILTERS = ['F277W-CLEAR','F356W-CLEAR','F444W-CLEAR',
              'F335M-CLEAR','F410M-CLEAR','F460M-CLEAR','F480M-CLEAR']

SW_FILTERS = ['F070W-CLEAR','F090W-CLEAR', 'F115W-CLEAR',
              'F150W-CLEAR','F200W-CLEAR', 'F210M-CLEAR' ]

WFC3IR_FILTERS = ['F160W','F140W','F125W','F110W','F105W','F098M']

ACS_FILTERS = ['F850LP','F814W','F606W','F435W','F438W','F775W']

for field in [field_to_run]:

    ix = np.where(fields['field'] == field)[0][0]

    pixel_scale = 0.04 # arcsec/pix

    hdu = utils.make_wcsheader(fields['ra'][ix], fields['dec'][ix],
                               size=(fields['nx'][ix]*2048*pixel_scale,
                                     fields['ny'][ix]*2048*pixel_scale),
                               pixscale=0.04, get_hdu=True)

    
    ir_wcs = pywcs.WCS(hdu.header)
    
    # Pull files from AWS and drizzle into a mosaic
    # NB: this will pull *any* exposure that overlaps with the defined WCS, 
    #     not just PANORAMIC from the query above. 

    root = f'panoramic-{field}-{mosaic_version}'
    for filt in LW_FILTERS:
        _ = visit_processor.cutout_mosaic(rootname=root,
                                      ir_wcs=ir_wcs,
                                      clean_flt=True,
                                      filters=[filt],
                                      half_optical=False,
                                      s3output=None,
                                      pixfrac=0.75,
                                      kernel='square',
                                      skip_existing=True,
                                      )
        gc.collect()
        # ! gzip {root}*{filt.lower()}*fits

    # SW run in a slightly weird way for memory issues?
    for filt in SW_FILTERS:
        _ = visit_processor.cutout_mosaic(rootname=root,
                                      ir_wcs=ir_wcs,
                                      clean_flt=True,
                                      filters=[filt],
                                      half_optical=True,
                                      s3output=None,
                                      pixfrac=0.75,
                                      kernel='square',
                                      skip_existing=True,
                                      )
        gc.collect()
        ! gzip {root}*{filt.lower()}*fits

    # HST at 40mas, just in case
    for filt in WFC3IR_FILTERS + ACS_FILTERS:
        _ = visit_processor.cutout_mosaic(rootname=root,
                                      ir_wcs=ir_wcs,
                                      clean_flt=True,
                                      filters=[filt],
                                      half_optical=False,
                                      s3output=None,
                                      pixfrac=0.75,
                                      kernel='square',
                                      skip_existing=True,
                                      )
# Out:
# ============ panoramic-j013444m1532-v6.0-f277w-clear============
#
# (   1/   8) Add exposure jw02514199001_06201_00001_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00025/Prep/jw02514199001_06201_00001_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2085  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F277W-CLEAR by 0.942
#   0    PHOTFLAM=3.66e-21, scale=0.942
#        PHOTFLAM=3.66e-21, scale=0.942
#   ext (SCI,1), sky=0.114 has_bkg:True median_weight:4.36e+03
#
#
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol
# # (2023-08-15 09:35:11.566)
# Drizzle array 1/1
#
# (   2/   8) Add exposure jw02514199001_06201_00001_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00020/Prep/jw02514199001_06201_00001_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 1920  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F277W-CLEAR by 1.000
#   0    PHOTFLAM=3.67e-21, scale=1.000
#        PHOTFLAM=3.67e-21, scale=1.003
#   ext (SCI,1), sky=0.114 has_bkg:True median_weight:4.73e+03
# # (2023-08-15 09:35:16.020)
# Drizzle array 1/1
#
# (   3/   8) Add exposure jw02514199001_06201_00002_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00025/Prep/jw02514199001_06201_00002_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2029  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F277W-CLEAR by 0.942
#   0    PHOTFLAM=3.66e-21, scale=0.942
#        PHOTFLAM=3.66e-21, scale=0.942
#   ext (SCI,1), sky=0.118 has_bkg:True median_weight:4.30e+03
# # (2023-08-15 09:35:19.195)
# Drizzle array 1/1
#
# (   4/   8) Add exposure jw02514199001_06201_00002_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00020/Prep/jw02514199001_06201_00002_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2120  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F277W-CLEAR by 1.000
#   0    PHOTFLAM=3.67e-21, scale=1.000
#        PHOTFLAM=3.67e-21, scale=1.003
#   ext (SCI,1), sky=0.111 has_bkg:True median_weight:4.79e+03
# # (2023-08-15 09:35:22.462)
# Drizzle array 1/1
#
# (   5/   8) Add exposure jw02514199001_06201_00003_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00025/Prep/jw02514199001_06201_00003_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2301  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F277W-CLEAR by 0.942
#   0    PHOTFLAM=3.66e-21, scale=0.942
#        PHOTFLAM=3.66e-21, scale=0.942
#   ext (SCI,1), sky=0.111 has_bkg:True median_weight:4.45e+03
# # (2023-08-15 09:35:25.720)
# Drizzle array 1/1
#
# (   6/   8) Add exposure jw02514199001_06201_00003_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00020/Prep/jw02514199001_06201_00003_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 1956  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F277W-CLEAR by 1.000
#   0    PHOTFLAM=3.67e-21, scale=1.000
#        PHOTFLAM=3.67e-21, scale=1.003
#   ext (SCI,1), sky=0.114 has_bkg:True median_weight:4.70e+03
# # (2023-08-15 09:35:28.821)
# Drizzle array 1/1
#
# (   7/   8) Add exposure jw02514199001_06201_00004_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00025/Prep/jw02514199001_06201_00004_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2416  ( 0.06 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F277W-CLEAR by 0.942
#   0    PHOTFLAM=3.66e-21, scale=0.942
#        PHOTFLAM=3.66e-21, scale=0.942
#   ext (SCI,1), sky=0.116 has_bkg:True median_weight:4.35e+03
# # (2023-08-15 09:35:31.970)
# Drizzle array 1/1
#
# (   8/   8) Add exposure jw02514199001_06201_00004_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f277w_00020/Prep/jw02514199001_06201_00004_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2177  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F277W-CLEAR by 1.000
#   0    PHOTFLAM=3.67e-21, scale=1.000
#        PHOTFLAM=3.67e-21, scale=1.003
#   ext (SCI,1), sky=0.115 has_bkg:True median_weight:4.69e+03
# # (2023-08-15 09:35:35.271)
# Drizzle array 1/1
# Scale PHOTFNU x 0.107 to 10.0 nJy
# ============ panoramic-j013444m1532-v6.0-f356w-clear============
#
# (   1/   8) Add exposure jw02514198001_04201_00001_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00015/Prep/jw02514198001_04201_00001_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 1945  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F356W-CLEAR by 1.021
#   0    PHOTFLAM=2.19e-21, scale=1.021
#        PHOTFLAM=2.19e-21, scale=1.021
#   ext (SCI,1), sky=0.102 has_bkg:True median_weight:5.22e+03
# # (2023-08-15 09:35:41.246)
# Drizzle array 1/1
#
# (   2/   8) Add exposure jw02514198001_04201_00001_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00014/Prep/jw02514198001_04201_00001_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 1854  ( 0.04 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F356W-CLEAR by 1.000
#   0    PHOTFLAM=2.19e-21, scale=1.000
#        PHOTFLAM=2.19e-21, scale=1.003
#   ext (SCI,1), sky=0.108 has_bkg:True median_weight:5.64e+03
# # (2023-08-15 09:35:44.663)
# Drizzle array 1/1
#
# (   3/   8) Add exposure jw02514198001_04201_00002_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00015/Prep/jw02514198001_04201_00002_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2077  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F356W-CLEAR by 1.021
#   0    PHOTFLAM=2.19e-21, scale=1.021
#        PHOTFLAM=2.19e-21, scale=1.021
#   ext (SCI,1), sky=0.101 has_bkg:True median_weight:5.27e+03
# # (2023-08-15 09:35:47.851)
# Drizzle array 1/1
#
# (   4/   8) Add exposure jw02514198001_04201_00002_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00014/Prep/jw02514198001_04201_00002_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2134  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F356W-CLEAR by 1.000
#   0    PHOTFLAM=2.19e-21, scale=1.000
#        PHOTFLAM=2.19e-21, scale=1.003
#   ext (SCI,1), sky=0.104 has_bkg:True median_weight:5.78e+03
# # (2023-08-15 09:35:51.046)
# Drizzle array 1/1
#
# (   5/   8) Add exposure jw02514198001_04201_00003_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00015/Prep/jw02514198001_04201_00003_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2104  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F356W-CLEAR by 1.021
#   0    PHOTFLAM=2.19e-21, scale=1.021
#        PHOTFLAM=2.19e-21, scale=1.021
#   ext (SCI,1), sky=0.104 has_bkg:True median_weight:5.17e+03
# # (2023-08-15 09:35:54.176)
# Drizzle array 1/1
#
# (   6/   8) Add exposure jw02514198001_04201_00003_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00014/Prep/jw02514198001_04201_00003_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2056  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F356W-CLEAR by 1.000
#   0    PHOTFLAM=2.19e-21, scale=1.000
#        PHOTFLAM=2.19e-21, scale=1.003
#   ext (SCI,1), sky=0.106 has_bkg:True median_weight:5.68e+03
# # (2023-08-15 09:35:57.313)
# Drizzle array 1/1
#
# (   7/   8) Add exposure jw02514198001_04201_00004_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00015/Prep/jw02514198001_04201_00004_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2835  ( 0.07 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F356W-CLEAR by 1.021
#   0    PHOTFLAM=2.19e-21, scale=1.021
#        PHOTFLAM=2.19e-21, scale=1.021
#   ext (SCI,1), sky=0.101 has_bkg:True median_weight:5.28e+03
# # (2023-08-15 09:36:00.497)
# Drizzle array 1/1
#
# (   8/   8) Add exposure jw02514198001_04201_00004_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f356w_00014/Prep/jw02514198001_04201_00004_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 2089  ( 0.05 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F356W-CLEAR by 1.000
#   0    PHOTFLAM=2.19e-21, scale=1.000
#        PHOTFLAM=2.19e-21, scale=1.003
#   ext (SCI,1), sky=0.104 has_bkg:True median_weight:5.76e+03
# # (2023-08-15 09:36:03.648)
# Drizzle array 1/1
# Scale PHOTFNU x 0.107 to 10.0 nJy
# ============ panoramic-j013444m1532-v6.0-f444w-clear============
#
# (   1/   8) Add exposure jw02514197001_02201_00001_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00009/Prep/jw02514197001_02201_00001_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 612  ( 0.01 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F444W-CLEAR by 1.001
#   0    PHOTFLAM=1.44e-21, scale=1.001
#        PHOTFLAM=1.44e-21, scale=1.001
#   ext (SCI,1), sky=0.263 has_bkg:True median_weight:2.94e+03
# # (2023-08-15 09:36:12.840)
# Drizzle array 1/1
#
# (   2/   8) Add exposure jw02514197001_02201_00001_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00002/Prep/jw02514197001_02201_00001_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 665  ( 0.02 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F444W-CLEAR by 1.000
#   0    PHOTFLAM=1.44e-21, scale=1.000
#        PHOTFLAM=1.44e-21, scale=1.003
#   ext (SCI,1), sky=0.266 has_bkg:True median_weight:3.05e+03
# # (2023-08-15 09:36:17.027)
# Drizzle array 1/1
#
# (   3/   8) Add exposure jw02514197001_02201_00002_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00009/Prep/jw02514197001_02201_00002_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 728  ( 0.02 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F444W-CLEAR by 1.001
#   0    PHOTFLAM=1.44e-21, scale=1.001
#        PHOTFLAM=1.44e-21, scale=1.001
#   ext (SCI,1), sky=0.260 has_bkg:True median_weight:2.97e+03
# # (2023-08-15 09:36:20.320)
# Drizzle array 1/1
#
# (   4/   8) Add exposure jw02514197001_02201_00002_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00002/Prep/jw02514197001_02201_00002_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 641  ( 0.02 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F444W-CLEAR by 1.000
#   0    PHOTFLAM=1.44e-21, scale=1.000
#        PHOTFLAM=1.44e-21, scale=1.003
#   ext (SCI,1), sky=0.266 has_bkg:True median_weight:3.03e+03
# # (2023-08-15 09:36:23.484)
# Drizzle array 1/1
#
# (   5/   8) Add exposure jw02514197001_02201_00003_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00009/Prep/jw02514197001_02201_00003_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 594  ( 0.01 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F444W-CLEAR by 1.001
#   0    PHOTFLAM=1.44e-21, scale=1.001
#        PHOTFLAM=1.44e-21, scale=1.001
#   ext (SCI,1), sky=0.264 has_bkg:True median_weight:2.93e+03
# # (2023-08-15 09:36:26.581)
# Drizzle array 1/1
#
# (   6/   8) Add exposure jw02514197001_02201_00003_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00002/Prep/jw02514197001_02201_00003_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 618  ( 0.01 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F444W-CLEAR by 1.000
#   0    PHOTFLAM=1.44e-21, scale=1.000
#        PHOTFLAM=1.44e-21, scale=1.003
#   ext (SCI,1), sky=0.265 has_bkg:True median_weight:3.05e+03
# # (2023-08-15 09:36:29.727)
# Drizzle array 1/1
#
# (   7/   8) Add exposure jw02514197001_02201_00004_nrcalong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00009/Prep/jw02514197001_02201_00004_nrcalong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCALONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 641  ( 0.02 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCALONG-F444W-CLEAR by 1.001
#   0    PHOTFLAM=1.44e-21, scale=1.001
#        PHOTFLAM=1.44e-21, scale=1.001
#   ext (SCI,1), sky=0.262 has_bkg:True median_weight:2.95e+03
# # (2023-08-15 09:36:32.909)
# Drizzle array 1/1
#
# (   8/   8) Add exposure jw02514197001_02201_00004_nrcblong_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f444w_00002/Prep/jw02514197001_02201_00004_nrcblong_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_badpix_20230710_NRCBLONG.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 641  ( 0.02 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: Scale NRCBLONG-F444W-CLEAR by 1.000
#   0    PHOTFLAM=1.44e-21, scale=1.000
#        PHOTFLAM=1.44e-21, scale=1.003
#   ext (SCI,1), sky=0.263 has_bkg:True median_weight:3.06e+03
# # (2023-08-15 09:36:36.041)
# Drizzle array 1/1
# Scale PHOTFNU x 0.107 to 10.0 nJy
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# gzip: panoramic-j013444m1532-v6.0*f070w-clear*fits: No such file or directory
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# gzip: panoramic-j013444m1532-v6.0*f090w-clear*fits: No such file or directory
# ============ panoramic-j013444m1532-v6.0-f115w-clear============
#
# (   1/  32) Add exposure jw02514197001_02201_00001_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00005/Prep/jw02514197001_02201_00001_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 141  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F115W-CLEAR not found
#   0    PHOTFLAM=5.14e-21, scale=1.000
#        PHOTFLAM=5.14e-21, scale=1.000
#   ext (SCI,1), sky=0.232 has_bkg:True median_weight:1.60e+02
# # (2023-08-15 09:36:48.611)
# Drizzle array 1/1
#
# (   2/  32) Add exposure jw02514197001_02201_00001_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00006/Prep/jw02514197001_02201_00001_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 130  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F115W-CLEAR not found
#   0    PHOTFLAM=5.00e-21, scale=1.000
#        PHOTFLAM=5.00e-21, scale=0.971
#   ext (SCI,1), sky=0.229 has_bkg:True median_weight:1.35e+02
# # (2023-08-15 09:36:52.553)
# Drizzle array 1/1
#
# (   3/  32) Add exposure jw02514197001_02201_00001_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00007/Prep/jw02514197001_02201_00001_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 197  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F115W-CLEAR not found
#   0    PHOTFLAM=5.19e-21, scale=1.000
#        PHOTFLAM=5.19e-21, scale=1.009
#   ext (SCI,1), sky=0.263 has_bkg:True median_weight:1.83e+02
# # (2023-08-15 09:36:55.854)
# Drizzle array 1/1
#
# (   4/  32) Add exposure jw02514197001_02201_00001_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00008/Prep/jw02514197001_02201_00001_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 182  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F115W-CLEAR not found
#   0    PHOTFLAM=5.04e-21, scale=1.000
#        PHOTFLAM=5.04e-21, scale=0.980
#   ext (SCI,1), sky=0.233 has_bkg:True median_weight:1.97e+02
# # (2023-08-15 09:36:59.156)
# Drizzle array 1/1
#
# (   5/  32) Add exposure jw02514197001_02201_00001_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00000/Prep/jw02514197001_02201_00001_nrcb1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 116  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB1-F115W-CLEAR not found
#   0    PHOTFLAM=4.99e-21, scale=1.000
#        PHOTFLAM=4.99e-21, scale=0.969
#   ext (SCI,1), sky=0.247 has_bkg:True median_weight:1.25e+02
# # (2023-08-15 09:37:02.445)
# Drizzle array 1/1
#
# (   6/  32) Add exposure jw02514197001_02201_00001_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00001/Prep/jw02514197001_02201_00001_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 141  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F115W-CLEAR not found
#   0    PHOTFLAM=5.13e-21, scale=1.000
#        PHOTFLAM=5.13e-21, scale=0.998
#   ext (SCI,1), sky=0.245 has_bkg:True median_weight:1.54e+02
# # (2023-08-15 09:37:05.920)
# Drizzle array 1/1
#
# (   7/  32) Add exposure jw02514197001_02201_00001_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00003/Prep/jw02514197001_02201_00001_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 75  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F115W-CLEAR not found
#   0    PHOTFLAM=5.03e-21, scale=1.000
#        PHOTFLAM=5.03e-21, scale=0.977
#   ext (SCI,1), sky=0.256 has_bkg:True median_weight:1.26e+02
# # (2023-08-15 09:37:09.223)
# Drizzle array 1/1
#
# (   8/  32) Add exposure jw02514197001_02201_00001_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00004/Prep/jw02514197001_02201_00001_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 181  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F115W-CLEAR not found
#   0    PHOTFLAM=5.18e-21, scale=1.000
#        PHOTFLAM=5.18e-21, scale=1.006
#   ext (SCI,1), sky=0.278 has_bkg:True median_weight:1.94e+02
# # (2023-08-15 09:37:12.555)
# Drizzle array 1/1
#
# (   9/  32) Add exposure jw02514197001_02201_00002_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00005/Prep/jw02514197001_02201_00002_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 188  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F115W-CLEAR not found
#   0    PHOTFLAM=5.14e-21, scale=1.000
#        PHOTFLAM=5.14e-21, scale=1.000
#   ext (SCI,1), sky=0.212 has_bkg:True median_weight:1.66e+02
# # (2023-08-15 09:37:17.757)
# Drizzle array 1/1
#
# (  10/  32) Add exposure jw02514197001_02201_00002_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00006/Prep/jw02514197001_02201_00002_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 137  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F115W-CLEAR not found
#   0    PHOTFLAM=5.00e-21, scale=1.000
#        PHOTFLAM=5.00e-21, scale=0.971
#   ext (SCI,1), sky=0.233 has_bkg:True median_weight:1.36e+02
# # (2023-08-15 09:37:21.122)
# Drizzle array 1/1
#
# (  11/  32) Add exposure jw02514197001_02201_00002_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00007/Prep/jw02514197001_02201_00002_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 207  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F115W-CLEAR not found
#   0    PHOTFLAM=5.19e-21, scale=1.000
#        PHOTFLAM=5.19e-21, scale=1.009
#   ext (SCI,1), sky=0.238 has_bkg:True median_weight:1.86e+02
# # (2023-08-15 09:37:24.430)
# Drizzle array 1/1
#
# (  12/  32) Add exposure jw02514197001_02201_00002_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00008/Prep/jw02514197001_02201_00002_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 134  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F115W-CLEAR not found
#   0    PHOTFLAM=5.04e-21, scale=1.000
#        PHOTFLAM=5.04e-21, scale=0.980
#   ext (SCI,1), sky=0.286 has_bkg:True median_weight:1.80e+02
# # (2023-08-15 09:37:27.845)
# Drizzle array 1/1
#
# (  13/  32) Add exposure jw02514197001_02201_00002_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00000/Prep/jw02514197001_02201_00002_nrcb1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 92  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB1-F115W-CLEAR not found
#   0    PHOTFLAM=4.99e-21, scale=1.000
#        PHOTFLAM=4.99e-21, scale=0.969
#   ext (SCI,1), sky=0.259 has_bkg:True median_weight:1.24e+02
# # (2023-08-15 09:37:31.061)
# Drizzle array 1/1
#
# (  14/  32) Add exposure jw02514197001_02201_00002_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00001/Prep/jw02514197001_02201_00002_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 158  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F115W-CLEAR not found
#   0    PHOTFLAM=5.13e-21, scale=1.000
#        PHOTFLAM=5.13e-21, scale=0.998
#   ext (SCI,1), sky=0.213 has_bkg:True median_weight:1.61e+02
# # (2023-08-15 09:37:34.315)
# Drizzle array 1/1
#
# (  15/  32) Add exposure jw02514197001_02201_00002_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00003/Prep/jw02514197001_02201_00002_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 92  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F115W-CLEAR not found
#   0    PHOTFLAM=5.03e-21, scale=1.000
#        PHOTFLAM=5.03e-21, scale=0.977
#   ext (SCI,1), sky=0.230 has_bkg:True median_weight:1.31e+02
# # (2023-08-15 09:37:37.563)
# Drizzle array 1/1
#
# (  16/  32) Add exposure jw02514197001_02201_00002_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00004/Prep/jw02514197001_02201_00002_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 158  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F115W-CLEAR not found
#   0    PHOTFLAM=5.18e-21, scale=1.000
#        PHOTFLAM=5.18e-21, scale=1.006
#   ext (SCI,1), sky=0.213 has_bkg:True median_weight:2.08e+02
# # (2023-08-15 09:37:40.871)
# Drizzle array 1/1
#
# (  17/  32) Add exposure jw02514197001_02201_00003_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00005/Prep/jw02514197001_02201_00003_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 180  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F115W-CLEAR not found
#   0    PHOTFLAM=5.14e-21, scale=1.000
#        PHOTFLAM=5.14e-21, scale=1.000
#   ext (SCI,1), sky=0.225 has_bkg:True median_weight:1.63e+02
# # (2023-08-15 09:37:44.222)
# Drizzle array 1/1
#
# (  18/  32) Add exposure jw02514197001_02201_00003_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00006/Prep/jw02514197001_02201_00003_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 200  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F115W-CLEAR not found
#   0    PHOTFLAM=5.00e-21, scale=1.000
#        PHOTFLAM=5.00e-21, scale=0.971
#   ext (SCI,1), sky=0.215 has_bkg:True median_weight:1.37e+02
# # (2023-08-15 09:37:47.530)
# Drizzle array 1/1
#
# (  19/  32) Add exposure jw02514197001_02201_00003_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00007/Prep/jw02514197001_02201_00003_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 201  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F115W-CLEAR not found
#   0    PHOTFLAM=5.19e-21, scale=1.000
#        PHOTFLAM=5.19e-21, scale=1.009
#   ext (SCI,1), sky=0.235 has_bkg:True median_weight:1.89e+02
# # (2023-08-15 09:37:50.734)
# Drizzle array 1/1
#
# (  20/  32) Add exposure jw02514197001_02201_00003_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00008/Prep/jw02514197001_02201_00003_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 157  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F115W-CLEAR not found
#   0    PHOTFLAM=5.04e-21, scale=1.000
#        PHOTFLAM=5.04e-21, scale=0.980
#   ext (SCI,1), sky=0.246 has_bkg:True median_weight:1.91e+02
# # (2023-08-15 09:37:54.124)
# Drizzle array 1/1
#
# (  21/  32) Add exposure jw02514197001_02201_00003_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00000/Prep/jw02514197001_02201_00003_nrcb1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 93  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB1-F115W-CLEAR not found
#   0    PHOTFLAM=4.99e-21, scale=1.000
#        PHOTFLAM=4.99e-21, scale=0.969
#   ext (SCI,1), sky=0.225 has_bkg:True median_weight:1.27e+02
# # (2023-08-15 09:37:57.417)
# Drizzle array 1/1
#
# (  22/  32) Add exposure jw02514197001_02201_00003_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00001/Prep/jw02514197001_02201_00003_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 120  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F115W-CLEAR not found
#   0    PHOTFLAM=5.13e-21, scale=1.000
#        PHOTFLAM=5.13e-21, scale=0.998
#   ext (SCI,1), sky=0.238 has_bkg:True median_weight:1.56e+02
# # (2023-08-15 09:38:00.743)
# Drizzle array 1/1
#
# (  23/  32) Add exposure jw02514197001_02201_00003_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00003/Prep/jw02514197001_02201_00003_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 90  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F115W-CLEAR not found
#   0    PHOTFLAM=5.03e-21, scale=1.000
#        PHOTFLAM=5.03e-21, scale=0.977
#   ext (SCI,1), sky=0.233 has_bkg:True median_weight:1.28e+02
# # (2023-08-15 09:38:03.970)
# Drizzle array 1/1
#
# (  24/  32) Add exposure jw02514197001_02201_00003_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00004/Prep/jw02514197001_02201_00003_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 170  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F115W-CLEAR not found
#   0    PHOTFLAM=5.18e-21, scale=1.000
#        PHOTFLAM=5.18e-21, scale=1.006
#   ext (SCI,1), sky=0.245 has_bkg:True median_weight:1.92e+02
# # (2023-08-15 09:38:07.218)
# Drizzle array 1/1
#
# (  25/  32) Add exposure jw02514197001_02201_00004_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00005/Prep/jw02514197001_02201_00004_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 166  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F115W-CLEAR not found
#   0    PHOTFLAM=5.14e-21, scale=1.000
#        PHOTFLAM=5.14e-21, scale=1.000
#   ext (SCI,1), sky=0.222 has_bkg:True median_weight:1.63e+02
# # (2023-08-15 09:38:10.532)
# Drizzle array 1/1
#
# (  26/  32) Add exposure jw02514197001_02201_00004_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00006/Prep/jw02514197001_02201_00004_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 135  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F115W-CLEAR not found
#   0    PHOTFLAM=5.00e-21, scale=1.000
#        PHOTFLAM=5.00e-21, scale=0.971
#   ext (SCI,1), sky=0.243 has_bkg:True median_weight:1.32e+02
# # (2023-08-15 09:38:13.850)
# Drizzle array 1/1
#
# (  27/  32) Add exposure jw02514197001_02201_00004_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00007/Prep/jw02514197001_02201_00004_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 206  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F115W-CLEAR not found
#   0    PHOTFLAM=5.19e-21, scale=1.000
#        PHOTFLAM=5.19e-21, scale=1.009
#   ext (SCI,1), sky=0.247 has_bkg:True median_weight:1.86e+02
# # (2023-08-15 09:38:17.132)
# Drizzle array 1/1
#
# (  28/  32) Add exposure jw02514197001_02201_00004_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00008/Prep/jw02514197001_02201_00004_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 154  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F115W-CLEAR not found
#   0    PHOTFLAM=5.04e-21, scale=1.000
#        PHOTFLAM=5.04e-21, scale=0.980
#   ext (SCI,1), sky=0.233 has_bkg:True median_weight:1.94e+02
# # (2023-08-15 09:38:20.350)
# Drizzle array 1/1
#
# (  29/  32) Add exposure jw02514197001_02201_00004_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00000/Prep/jw02514197001_02201_00004_nrcb1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 96  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB1-F115W-CLEAR not found
#   0    PHOTFLAM=4.99e-21, scale=1.000
#        PHOTFLAM=4.99e-21, scale=0.969
#   ext (SCI,1), sky=0.262 has_bkg:True median_weight:1.23e+02
# # (2023-08-15 09:38:23.533)
# Drizzle array 1/1
#
# (  30/  32) Add exposure jw02514197001_02201_00004_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00001/Prep/jw02514197001_02201_00004_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 142  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F115W-CLEAR not found
#   0    PHOTFLAM=5.13e-21, scale=1.000
#        PHOTFLAM=5.13e-21, scale=0.998
#   ext (SCI,1), sky=0.210 has_bkg:True median_weight:1.60e+02
# # (2023-08-15 09:38:26.732)
# Drizzle array 1/1
#
# (  31/  32) Add exposure jw02514197001_02201_00004_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00003/Prep/jw02514197001_02201_00004_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 73  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F115W-CLEAR not found
#   0    PHOTFLAM=5.03e-21, scale=1.000
#        PHOTFLAM=5.03e-21, scale=0.977
#   ext (SCI,1), sky=0.273 has_bkg:True median_weight:1.26e+02
# # (2023-08-15 09:38:30.042)
# Drizzle array 1/1
#
# (  32/  32) Add exposure jw02514197001_02201_00004_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f115w_00004/Prep/jw02514197001_02201_00004_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 153  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F115W-CLEAR not found
#   0    PHOTFLAM=5.18e-21, scale=1.000
#        PHOTFLAM=5.18e-21, scale=1.006
#   ext (SCI,1), sky=0.236 has_bkg:True median_weight:1.96e+02
# # (2023-08-15 09:38:33.356)
# Drizzle array 1/1
# Scale PHOTFNU x 0.436 to 10.0 nJy
# ============ panoramic-j013444m1532-v6.0-f150w-clear============
#
# (   1/  32) Add exposure jw02514198001_04201_00001_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f150w_00018/Prep/jw02514198001_04201_00001_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 208  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F150W-CLEAR not found
#   0    PHOTFLAM=3.04e-21, scale=1.000
#        PHOTFLAM=3.04e-21, scale=1.000
#   ext (SCI,1), sky=0.203 has_bkg:True median_weight:2.71e+02
# # (2023-08-15 09:39:15.354)
# Drizzle array 1/1
#
# (   2/  32) Add exposure jw02514198001_04201_00001_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f150w_00017/Prep/jw02514198001_04201_00001_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 149  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F150W-CLEAR not found
#   0    PHOTFLAM=2.96e-21, scale=1.000
#        PHOTFLAM=2.96e-21, scale=0.971
#   ext (SCI,1), sky=0.248 has_bkg:True median_weight:2.14e+02
# # (2023-08-15 09:39:19.209)
# Drizzle array 1/1
#
# (   3/  32) Add exposure jw02514198001_04201_00001_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f150w_00016/Prep/jw02514198001_04201_00001_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 237  ( 0.006 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F150W-CLEAR not found
#   0    PHOTFLAM=3.07e-21, scale=1.000
#        PHOTFLAM=3.07e-21, scale=1.009
#   ext (SCI,1), sky=0.229 has_bkg:True median_weight:3.11e+02
# # (2023-08-15 09:39:22.561)
# Drizzle array 1/1
#
# (   4/  32) Add exposure jw02514198001_04201_00001_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f150w_00019/Prep/jw02514198001_04201_00001_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 151  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F150W-CLEAR not found
#   0    PHOTFLAM=2.98e-21, scale=1.000
#        PHOTFLAM=2.98e-21, scale=0.980
#   ext (SCI,1), sky=0.265 has_bkg:True median_weight:2.96e+02
# # (2023-08-15 09:39:25.982)
# Drizzle array 1/1
#
# (   5/  32) Add exposure jw02514198001_04201_00001_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f150w_00011/Prep/jw02514198001_04201_00001_nrcb1_rate.fits)
# ...
#   ext (SCI,1), sky=0.192 has_bkg:True median_weight:3.11e+02
# # (2023-08-15 09:42:21.301)
# Drizzle array 1/1
#
# (  14/  32) Add exposure jw02514199001_06201_00002_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00022/Prep/jw02514199001_06201_00002_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 129  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F200W-CLEAR not found
#   0    PHOTFLAM=1.73e-21, scale=1.000
#        PHOTFLAM=1.73e-21, scale=0.998
#   ext (SCI,1), sky=0.190 has_bkg:True median_weight:3.69e+02
# # (2023-08-15 09:42:24.499)
# Drizzle array 1/1
#
# (  15/  32) Add exposure jw02514199001_06201_00002_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00024/Prep/jw02514199001_06201_00002_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 71  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F200W-CLEAR not found
#   0    PHOTFLAM=1.69e-21, scale=1.000
#        PHOTFLAM=1.69e-21, scale=0.977
#   ext (SCI,1), sky=0.178 has_bkg:True median_weight:3.23e+02
# # (2023-08-15 09:42:27.783)
# Drizzle array 1/1
#
# (  16/  32) Add exposure jw02514199001_06201_00002_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00023/Prep/jw02514199001_06201_00002_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 173  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F200W-CLEAR not found
#   0    PHOTFLAM=1.74e-21, scale=1.000
#        PHOTFLAM=1.74e-21, scale=1.006
#   ext (SCI,1), sky=0.172 has_bkg:True median_weight:4.52e+02
# # (2023-08-15 09:42:31.079)
# Drizzle array 1/1
#
# (  17/  32) Add exposure jw02514199001_06201_00003_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00026/Prep/jw02514199001_06201_00003_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 152  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F200W-CLEAR not found
#   0    PHOTFLAM=1.73e-21, scale=1.000
#        PHOTFLAM=1.73e-21, scale=1.000
#   ext (SCI,1), sky=0.179 has_bkg:True median_weight:3.74e+02
# # (2023-08-15 09:42:34.466)
# Drizzle array 1/1
#
# (  18/  32) Add exposure jw02514199001_06201_00003_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00027/Prep/jw02514199001_06201_00003_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 187  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F200W-CLEAR not found
#   0    PHOTFLAM=1.68e-21, scale=1.000
#        PHOTFLAM=1.68e-21, scale=0.971
#   ext (SCI,1), sky=0.201 has_bkg:True median_weight:2.81e+02
# # (2023-08-15 09:42:37.748)
# Drizzle array 1/1
#
# (  19/  32) Add exposure jw02514199001_06201_00003_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00028/Prep/jw02514199001_06201_00003_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 218  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F200W-CLEAR not found
#   0    PHOTFLAM=1.75e-21, scale=1.000
#        PHOTFLAM=1.75e-21, scale=1.009
#   ext (SCI,1), sky=0.176 has_bkg:True median_weight:4.60e+02
# # (2023-08-15 09:42:41.214)
# Drizzle array 1/1
#
# (  20/  32) Add exposure jw02514199001_06201_00003_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00029/Prep/jw02514199001_06201_00003_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 211  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F200W-CLEAR not found
#   0    PHOTFLAM=1.70e-21, scale=1.000
#        PHOTFLAM=1.70e-21, scale=0.980
#   ext (SCI,1), sky=0.199 has_bkg:True median_weight:4.15e+02
# # (2023-08-15 09:42:44.555)
# Drizzle array 1/1
#
# (  21/  32) Add exposure jw02514199001_06201_00003_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00021/Prep/jw02514199001_06201_00003_nrcb1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 116  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB1-F200W-CLEAR not found
#   0    PHOTFLAM=1.68e-21, scale=1.000
#        PHOTFLAM=1.68e-21, scale=0.969
#   ext (SCI,1), sky=0.191 has_bkg:True median_weight:3.11e+02
# # (2023-08-15 09:42:47.925)
# Drizzle array 1/1
#
# (  22/  32) Add exposure jw02514199001_06201_00003_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00022/Prep/jw02514199001_06201_00003_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 159  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F200W-CLEAR not found
#   0    PHOTFLAM=1.73e-21, scale=1.000
#        PHOTFLAM=1.73e-21, scale=0.998
#   ext (SCI,1), sky=0.172 has_bkg:True median_weight:3.78e+02
# # (2023-08-15 09:42:51.180)
# Drizzle array 1/1
#
# (  23/  32) Add exposure jw02514199001_06201_00003_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00024/Prep/jw02514199001_06201_00003_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 93  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F200W-CLEAR not found
#   0    PHOTFLAM=1.69e-21, scale=1.000
#        PHOTFLAM=1.69e-21, scale=0.977
#   ext (SCI,1), sky=0.179 has_bkg:True median_weight:3.29e+02
# # (2023-08-15 09:42:54.577)
# Drizzle array 1/1
#
# (  24/  32) Add exposure jw02514199001_06201_00003_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00023/Prep/jw02514199001_06201_00003_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 160  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F200W-CLEAR not found
#   0    PHOTFLAM=1.74e-21, scale=1.000
#        PHOTFLAM=1.74e-21, scale=1.006
#   ext (SCI,1), sky=0.183 has_bkg:True median_weight:4.35e+02
# # (2023-08-15 09:42:57.935)
# Drizzle array 1/1
#
# (  25/  32) Add exposure jw02514199001_06201_00004_nrca1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00026/Prep/jw02514199001_06201_00004_nrca1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 162  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA1-F200W-CLEAR not found
#   0    PHOTFLAM=1.73e-21, scale=1.000
#        PHOTFLAM=1.73e-21, scale=1.000
#   ext (SCI,1), sky=0.192 has_bkg:True median_weight:3.68e+02
# # (2023-08-15 09:43:01.294)
# Drizzle array 1/1
#
# (  26/  32) Add exposure jw02514199001_06201_00004_nrca2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00027/Prep/jw02514199001_06201_00004_nrca2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 126  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA2-F200W-CLEAR not found
#   0    PHOTFLAM=1.68e-21, scale=1.000
#        PHOTFLAM=1.68e-21, scale=0.971
#   ext (SCI,1), sky=0.206 has_bkg:True median_weight:2.82e+02
# # (2023-08-15 09:43:04.634)
# Drizzle array 1/1
#
# (  27/  32) Add exposure jw02514199001_06201_00004_nrca3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00028/Prep/jw02514199001_06201_00004_nrca3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 239  ( 0.006 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA3-F200W-CLEAR not found
#   0    PHOTFLAM=1.75e-21, scale=1.000
#        PHOTFLAM=1.75e-21, scale=1.009
#   ext (SCI,1), sky=0.176 has_bkg:True median_weight:4.60e+02
# # (2023-08-15 09:43:08.294)
# Drizzle array 1/1
#
# (  28/  32) Add exposure jw02514199001_06201_00004_nrca4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00029/Prep/jw02514199001_06201_00004_nrca4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCA4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 211  ( 0.005 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCA4-F200W-CLEAR not found
#   0    PHOTFLAM=1.70e-21, scale=1.000
#        PHOTFLAM=1.70e-21, scale=0.980
#   ext (SCI,1), sky=0.183 has_bkg:True median_weight:4.37e+02
# # (2023-08-15 09:43:11.680)
# Drizzle array 1/1
#
# (  29/  32) Add exposure jw02514199001_06201_00004_nrcb1_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00021/Prep/jw02514199001_06201_00004_nrcb1_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB1.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 129  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB1-F200W-CLEAR not found
#   0    PHOTFLAM=1.68e-21, scale=1.000
#        PHOTFLAM=1.68e-21, scale=0.969
#   ext (SCI,1), sky=0.196 has_bkg:True median_weight:3.09e+02
# # (2023-08-15 09:43:14.982)
# Drizzle array 1/1
#
# (  30/  32) Add exposure jw02514199001_06201_00004_nrcb2_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00022/Prep/jw02514199001_06201_00004_nrcb2_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB2.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 167  ( 0.004 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB2-F200W-CLEAR not found
#   0    PHOTFLAM=1.73e-21, scale=1.000
#        PHOTFLAM=1.73e-21, scale=0.998
#   ext (SCI,1), sky=0.178 has_bkg:True median_weight:3.82e+02
# # (2023-08-15 09:43:18.329)
# Drizzle array 1/1
#
# (  31/  32) Add exposure jw02514199001_06201_00004_nrcb3_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00024/Prep/jw02514199001_06201_00004_nrcb3_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB3.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 94  ( 0.002 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB3-F200W-CLEAR not found
#   0    PHOTFLAM=1.69e-21, scale=1.000
#        PHOTFLAM=1.69e-21, scale=0.977
#   ext (SCI,1), sky=0.181 has_bkg:True median_weight:3.26e+02
# # (2023-08-15 09:43:21.680)
# Drizzle array 1/1
#
# (  32/  32) Add exposure jw02514199001_06201_00004_nrcb4_rate.fits (weight_type='err', rnoise_percentile=99)
#
#   (fetch from s3://grizli-v2/HST/Pipeline/j013444m1532_indef-f200w_00023/Prep/jw02514199001_06201_00004_nrcb4_rate.fits)
# Use extra badpix in /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/nrc_lowpix_0916_NRCB4.fits.gz
# # prep.apply_region_mask_from_db: query failed
# Extra -5 sigma low pixels: N= 133  ( 0.003 %)
# get_photom_scale /usr/local/python/3.10.8/lib/python3.10/site-packages/grizli/data/photom_correction.yml: NRCB4-F200W-CLEAR not found
#   0    PHOTFLAM=1.74e-21, scale=1.000
#        PHOTFLAM=1.74e-21, scale=1.006
#   ext (SCI,1), sky=0.181 has_bkg:True median_weight:4.41e+02
# # (2023-08-15 09:43:25.149)
# Drizzle array 1/1
# Scale PHOTFNU x 0.436 to 10.0 nJy
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# gzip: panoramic-j013444m1532-v6.0*f210m-clear*fits: No such file or directory
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)
# No exposures found overlapping output wcs with corners = (23.651669,-15.588080), (23.722531,-15.474314)

# %% [markdown]
# ### RGB image

# %%
# RGB mosaic
def make_rgb(root, full_dimensions=2, scl=2.0):
    """
    Make RGB image
    """

    files = glob.glob(f"{root}*-f*clear*sci.fits*")
    files.sort()    

    filters = [f.split('-')[-2] + '-clear' for f in files]
    filters.sort()
    print(filters)

    auto_script.IMSAVE_QUALITY = 99

    norm = {'stretch': 'asinh', 'min_cut': -0.01, 
                                            'max_cut': 5.0, 'clip':True, 
                                            'asinh_a':0.010}

    im = pyfits.open(files[-1])

    msk = im[0].data != 0
    yp , xp = np.indices(msk.shape)
    spad = 64
    xyslice = (slice(np.maximum(xp[msk].min()-spad, 0), xp[msk].max()+spad), 
                slice(np.maximum(yp[msk].min()-spad, 0), yp[msk].max()+spad))

    print('slice: ', xyslice)

    filts = ['f356w-clear','f150w-clear','f115w-clear']
    rgb_scl = [1.0, 0.95, 1.02]

    if 'f444w-clear' in filters:
        filts = ['f444w-clear','f277w-clear','f115w-clear']

    rgb = auto_script.field_rgb(root,
                            HOME_PATH=None, gzext='*', 
                            filters=filts,
                            force_rgb=filts,
                            rgb_scl=rgb_scl,
                            full_dimensions=full_dimensions,
                            scl=scl,
                            suffix='.rgb',
                            xsize=128,
                            xyslice=xyslice,
                            add_labels=False,
                            norm_kwargs=norm,
                            output_format='png',
                            fill_black=True,
                            pl=2.0, pf=1)

    plt.close('all')

# %%
if False: # Not enough memory on GitHub/codespace
    if (not os.path.exists(f'{root}.rgb.png')):
        make_rgb(root, full_dimensions=2, scl=2.0)
    else:
        print('RGB image found')
else:
    print('Not making RGB images....')
# Out:
# Not making RGB images....

# %% [markdown]
# ### Detection image and catalog
#
# LW detection image weighted by constant Fnu
#
# Photometric catalog tends to run out of disk space...

# %%
from grizli.pipeline import auto_script
from grizli import prep
import astropy.io.fits as pyfits

comb = {'ir':['F444W-CLEAR','F356W-CLEAR','F277W-CLEAR',
              'F430M-CLEAR','F460M-CLEAR','F480M-CLEAR', 
              'CLEARP-F277W','CLEARP-F356W', 'CLEARP-F444W']}

block_filters = ['F090W-CLEAR','F115W-CLEAR','F150W-CLEAR','F200W-CLEAR']

# Not enough memory on GitHub/codespace?
MAKE_CATALOG = False

for field in fields['field']:
    root = f'panoramic-{field}-{mosaic_version}'

    files = glob.glob(f'{root}*sci.fits*')
    if len(files) == 0:
        continue
    
    if len(glob.glob(f'{root}-ir_drc_sci.fits*')) == 0:
        status = auto_script.make_filter_combinations(root,
                                                  filter_combinations=comb, 
                                                  weight_fnu=2, 
                                                  force_photfnu=1.e-8,
                                                  block_filters=block_filters
                                                 )
    
    # Make the photometric catalog
    phot_apertures = prep.SEXTRACTOR_PHOT_APERTURES_ARCSEC[:4]
    
    # Skip catalogs for now, since they make "bkg" images that fill up the disk quota
    if (not os.path.exists(f'{root}_phot.fits')) & MAKE_CATALOG:
        try:
            auto_script.multiband_catalog(field_root=root, 
                                      threshold=1.2, 
                                      bkg_params={'bw': 50, 'bh': 50,
                                                  'fw': 3, 'fh': 3,
                                                  'pixel_scale': pixel_scale}, 
                                      get_all_filters=True,
                                      phot_err_scale=1.0, 
                                      phot_apertures=phot_apertures,
                                      )
    
            phot = utils.read_catalog(f'{root}_phot.fits')
        except OSError:
            pass

        ! rm {root}*bkg.fits
        ! gzip {root}*seg.fits
# Out:
# panoramic-j013444m1532-v6.0-f277w-clear_drc_sci.fits f277w-clear ir block_reduce=False scl=1.0 scl_wht=1.0
# panoramic-j013444m1532-v6.0-f356w-clear_drc_sci.fits f356w-clear ir block_reduce=False scl=1.0 scl_wht=1.0
# panoramic-j013444m1532-v6.0-f444w-clear_drc_sci.fits f444w-clear ir block_reduce=False scl=1.0 scl_wht=1.0
# Write panoramic-j013444m1532-v6.0-ir_drc_sci.fits

# %% [markdown]
# ### Sync to S3

# %%
import astropy.time

for field in fields['field']:
    root = f'panoramic-{field}-{mosaic_version}'

    files = glob.glob(f'{root}*sci.fits*')
    if len(files) == 0:
        continue

    # Upload to S3
    ! rm {root}*bkg.fits

    files = glob.glob(f'{root}*_dr*fits')
    files += glob.glob(f'{root}*seg.fits')
    files.sort()
    
    for file in files:
        print(f'gzip {file}')
        ! gzip {file}

    s3path = f's3://grizli-panoramic/mosaics/{mosaic_version}/{field}/'

    ! aws s3 sync ./ {s3path} --exclude "*" --include "{root}*gz" --include "{root}*csv" --include "{root}*phot.fits" --include "{root}*cat.fits" --include "*{field}*png" --acl public-read

    extra_html = f"<img src=panoramic-{field}.png height=400px> <img src={root}.rgb.png height=400px> \n<br>"

    filter_files = glob.glob(f'{root}*fp.png')
    filter_files.sort()
    for file in filter_files:
        extra_html += f"<img src={file} height=200px>\n"

    extra_html += "<pre>\n# filter  expstart  ndrizim  exptime\n"
    files = glob.glob(f'{root}-f*_dr*sci.fits.gz')
    files.sort()
    for file in files:
        with pyfits.open(file) as im:
            expfact = 1.
            if im[0].header['INSTRUME'] == 'NIRCAM':
                if im[0].header['DETECTOR'] in ['NRCALONG','NRCBLONG']:
                    expfact = 2
                else:
                    expfact = 8

            row = f"{im[0].header['FILTER']} {im[0].header['EXPSTART']:.2f}  {im[0].header['NDRIZIM']//expfact}  {im[0].header['EXPTIME']/expfact:.1f}"

            print(row)
            extra_html += row + '\n'

    extra_html += f"</pre>\n"

    create_s3_index(s3path, output_file="index.html", extra_html=extra_html, upload=True)
    
    # Add to log
    log = utils.read_catalog('mosaic_log.txt')
    done = (log['field'] == field) & (log['version'] == mosaic_version)
    if done.sum() == 0:
        print(f'Add {field} {mosaic_version} to log.')

        with open('mosaic_log.txt','a') as fp:
            fp.write(f'{field}  {mosaic_version}  {astropy.time.Time.now().iso}\n')
# Out:
# rm: cannot remove 'panoramic-j013444m1532-v6.0*bkg.fits': No such file or directory
# gzip panoramic-j013444m1532-v6.0-f277w-clear_drc_sci.fits
# gzip panoramic-j013444m1532-v6.0-f277w-clear_drc_wht.fits
# gzip panoramic-j013444m1532-v6.0-f356w-clear_drc_sci.fits
# gzip panoramic-j013444m1532-v6.0-f356w-clear_drc_wht.fits
# gzip panoramic-j013444m1532-v6.0-f444w-clear_drc_sci.fits
# gzip panoramic-j013444m1532-v6.0-f444w-clear_drc_wht.fits
# gzip panoramic-j013444m1532-v6.0-ir_drc_sci.fits
# gzip panoramic-j013444m1532-v6.0-ir_drc_wht.fits
# upload: ./panoramic-j013444m1532-v6.0-f115w-clear_wcs.csv to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f115w-clear_wcs.csv
# upload: ./panoramic-j013444m1532-v6.0-f115w-clear_fp.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f115w-clear_fp.png
# upload: ./panoramic-j013444m1532-v6.0-f150w-clear_fp.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f150w-clear_fp.png
# upload: ./panoramic-j013444m1532-v6.0-f150w-clear_wcs.csv to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f150w-clear_wcs.csv
# upload: ./panoramic-j013444m1532-v6.0-f115w-clear_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f115w-clear_drc_wht.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f150w-clear_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f150w-clear_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f200w-clear_fp.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f200w-clear_fp.png
# upload: ./panoramic-j013444m1532-v6.0-f150w-clear_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f150w-clear_drc_wht.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f200w-clear_wcs.csv to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f200w-clear_wcs.csv
# upload: ./panoramic-j013444m1532-v6.0-f277w-clear_fp.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f277w-clear_fp.png
# upload: ./panoramic-j013444m1532-v6.0-f115w-clear_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f115w-clear_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f277w-clear_wcs.csv to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f277w-clear_wcs.csv
# upload: ./panoramic-j013444m1532-v6.0-f200w-clear_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f200w-clear_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f277w-clear_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f277w-clear_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f277w-clear_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f277w-clear_drc_wht.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f356w-clear_fp.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f356w-clear_fp.png
# upload: ./panoramic-j013444m1532-v6.0-f356w-clear_wcs.csv to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f356w-clear_wcs.csv
# upload: ./panoramic-j013444m1532-v6.0-f356w-clear_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f356w-clear_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f444w-clear_fp.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f444w-clear_fp.png
# upload: ./panoramic-j013444m1532-v6.0-f356w-clear_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f356w-clear_drc_wht.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f444w-clear_wcs.csv to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f444w-clear_wcs.csv
# upload: ./panoramic-j013444m1532.png to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532.png
# upload: ./panoramic-j013444m1532-v6.0-f444w-clear_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f444w-clear_drc_wht.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f444w-clear_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f444w-clear_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-ir_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-ir_drc_wht.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-ir_drc_sci.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-ir_drc_sci.fits.gz
# upload: ./panoramic-j013444m1532-v6.0-f200w-clear_drc_wht.fits.gz to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/panoramic-j013444m1532-v6.0-f200w-clear_drc_wht.fits.gz
# F115W 60169.93  4  944.8
# F150W 60169.95  4  944.8
# F200W 60169.97  4  944.8
# F277W 60169.97  4  944.8
# F356W 60169.95  4  944.8
# F444W 60169.93  4  944.8
# upload: ./index.html to s3://grizli-panoramic/mosaics/v6.0/j013444m1532/index.html
# https://s3.amazonaws.com/grizli-panoramic/mosaics/v6.0/j013444m1532/index.html
# index.html
# Add j013444m1532 v6.0 to log.

# %% [markdown]
# ## Master HTML log for all processed mosaics
#
# Don't delete `mosaic_log.txt` if clearing out files to make space!

# %%
! cat mosaic_log.txt
# Out:
# # field  version date time
# j090000p0207  v6.0  2023-05-04 09:44:57.191
# j145652p2444  v6.0  2023-05-04 10:37:56.604
# j093144p0819  v6.0  2023-05-04 11:16:46.528
# j100736p2109  v6.0  2023-05-10 16:07:03.162
# j093452p6116  v6.0  2023-05-10 18:43:31.732
# j125652p5652  v6.0  2023-05-10 18:44:39.470
# j150604p5409  v6.0  2023-05-10 19:45:12.123
# j170720p5853  v6.0  2023-05-10 20:00:33.283
# j094232p0923  v6.0  2023-05-10 20:12:52.988
# j153500p2325  v6.0  2023-05-10 22:13:33.482
# j131432p2432  v6.0  2023-06-13 13:57:40.377
# j134348p5549  v6.0  2023-06-13 14:20:56.488
# j121932p0330  v6.0  2023-06-14 13:06:03.030
# j142536p5630  v6.0  2023-06-29 19:20:17.000
# j130016p1215  v6.0  2023-06-29 20:56:29.000
# j144904m1017  v6.0  2023-07-04 17:49:08.950
# j123140m1618  v6.0  2023-07-04 18:35:28.420
# j000352m1120  v6.0  2023-07-19 21:19:40.026
# j043844m6849  v6.0  2023-08-01 17:44:07.158
# j021824m0517  v6.0  2023-08-01 18:12:07.183
# j234512m4235  v6.0  2023-08-01 21:22:38.265
# j010408m5508  v6.0  2023-08-07 22:03:14.504
# j021728m0214  v6.0  2023-08-07 22:38:49.899
# j224612m0527  v6.0  2023-08-10 19:29:25.273
# j224604m0518  v6.0  2023-08-12 17:20:14.846
# j224616m0531  v6.0  2023-08-12 20:37:07.216
# j013444m1532  v6.0  2023-08-15 09:45:42.016

# %%
log = utils.read_catalog('mosaic_log.txt')

un = utils.Unique(log['version'])

with open('mosaics.html','w') as fp:
    for v in un.values:
        fp.write(f'<h3> Version {v} </h3>\n')

        for i in np.where(un[v])[0]:
            s3 = f"https://s3.amazonaws.com/grizli-panoramic/mosaics/{v}/{log['field'][i]}/index.html"
            fp.write(f"{log['date'][i]} {log['time'][i]} <a href=\"{s3}\" /> {log['field'][i]} </a> <br> \n")

    fp.write(f'<h3> Fields </h3>\n')
    for field in fields['field']:
        fp.write(f'<p> {field} </p> <img src=panoramic-{field}.png height=300px /> \n')

! aws s3 sync ./ s3://grizli-panoramic/mosaics/ --exclude "*" --include "mosaics.html" --include "panoramic*png" --exclude "*fp.png" --acl public-read
# Out:
#    N  value
# ====  ==========
#   27  v6.0
# upload: ./mosaics.html to s3://grizli-panoramic/mosaics/mosaics.html
# upload: ./panoramic-j094232p0923.png to s3://grizli-panoramic/mosaics/panoramic-j094232p0923.png
# upload: ./panoramic-j021728m0214.png to s3://grizli-panoramic/mosaics/panoramic-j021728m0214.png
# upload: ./panoramic-j000352m1120.png to s3://grizli-panoramic/mosaics/panoramic-j000352m1120.png
# upload: ./panoramic-j010408m5508.png to s3://grizli-panoramic/mosaics/panoramic-j010408m5508.png
# upload: ./panoramic-j090000p0207.png to s3://grizli-panoramic/mosaics/panoramic-j090000p0207.png
# upload: ./panoramic-j093144p0819.png to s3://grizli-panoramic/mosaics/panoramic-j093144p0819.png
# upload: ./panoramic-j013444m1532.png to s3://grizli-panoramic/mosaics/panoramic-j013444m1532.png
# upload: ./panoramic-j093452p6116.png to s3://grizli-panoramic/mosaics/panoramic-j093452p6116.png
# upload: ./panoramic-j043844m6849.png to s3://grizli-panoramic/mosaics/panoramic-j043844m6849.png
# upload: ./panoramic-j021824m0517.png to s3://grizli-panoramic/mosaics/panoramic-j021824m0517.png
# upload: ./panoramic-j121932p0330.png to s3://grizli-panoramic/mosaics/panoramic-j121932p0330.png
# upload: ./panoramic-j123140m1618.png to s3://grizli-panoramic/mosaics/panoramic-j123140m1618.png
# upload: ./panoramic-j125652p5652.png to s3://grizli-panoramic/mosaics/panoramic-j125652p5652.png
# upload: ./panoramic-j100736p2109.png to s3://grizli-panoramic/mosaics/panoramic-j100736p2109.png
# upload: ./panoramic-j130016p1215.png to s3://grizli-panoramic/mosaics/panoramic-j130016p1215.png
# upload: ./panoramic-j123800p6217.png to s3://grizli-panoramic/mosaics/panoramic-j123800p6217.png
# upload: ./panoramic-j142536p5630.png to s3://grizli-panoramic/mosaics/panoramic-j142536p5630.png
# upload: ./panoramic-j134348p5549.png to s3://grizli-panoramic/mosaics/panoramic-j134348p5549.png
# upload: ./panoramic-j141932p5254.png to s3://grizli-panoramic/mosaics/panoramic-j141932p5254.png
# upload: ./panoramic-j131432p2432.png to s3://grizli-panoramic/mosaics/panoramic-j131432p2432.png
# upload: ./panoramic-j145652p2444.png to s3://grizli-panoramic/mosaics/panoramic-j145652p2444.png
# upload: ./panoramic-j150604p5409.png to s3://grizli-panoramic/mosaics/panoramic-j150604p5409.png
# upload: ./panoramic-j144904m1017.png to s3://grizli-panoramic/mosaics/panoramic-j144904m1017.png
# upload: ./panoramic-j170720p5853.png to s3://grizli-panoramic/mosaics/panoramic-j170720p5853.png
# upload: ./panoramic-j234512m4235.png to s3://grizli-panoramic/mosaics/panoramic-j234512m4235.png
# upload: ./panoramic-j153500p2325.png to s3://grizli-panoramic/mosaics/panoramic-j153500p2325.png
# upload: ./panoramic-j224612m0527.png to s3://grizli-panoramic/mosaics/panoramic-j224612m0527.png

# %%
# !df -h .
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop3       32G   19G   12G  61% /workspaces

# %% [markdown]
# # Summary HTML hosted on github pages
#
# Make a markdown file that will be rendered at https://gbrammer.github.io/panoramic-jwst/Mosaics/summary

# %%
from grizli.aws import db
full = db.SQL("""select assoc, crval1 as ra, crval2 as dec, dataset, filter, detector, exptime, expstart from exposure_files
where dataset like 'jw02514%%'
order by assoc, filter""")

full['parent'] = [a.split('_')[0] for a in full['assoc']]
       
# Split double field j224612m0527
test = full['parent'] == 'j224612m0527'
south = (full['dec'] < -5.4)
print((test & south).sum(), (test & ~south).sum())

parent = full['parent'].tolist()

for i in np.where(test & south)[0]:
    parent[i]= utils.radec_to_targname(full['ra'][test & south].mean(), full['dec'][test & south].mean())
for i in np.where(test & ~south)[0]:
    parent[i]= utils.radec_to_targname(full['ra'][test & ~south].mean(), full['dec'][test & ~south].mean())
    
full['parent'] = parent

# Merge MACS0416
dr = np.sqrt((full['ra']-64.061150)**2 +  (full['dec'] + 24.144900)**2)
macs0416 = dr < 0.4
if macs0416.sum() >  0:
    print(f"Merge {np.unique(full['parent'][macs0416]).tolist()} > 'j041616m2409'")
    full['parent'][macs0416] = 'j041616m2409'

len(full)
# Out:
# 430 180
# Merge ['j041616m2409', 'j041624m2411'] > 'j041616m2409'
# 5365

# %%
from grizli import utils
import numpy as np
import astropy.time
import time

# utils.Unique(full['filter'])
filters = np.unique(full['filter'])

with open('../Mosaics/summary.md','w') as fp:
    
    fp.write(f"""
![Alt text](../PanoramicLogo.png?raw=true "PanoramicLogo")

PANORAMIC Fields
----------------

- Exposure times in ks
- [Visit Status](https://www.stsci.edu/cgi-bin/get-visit-status?id=2514&markupFormat=html&observatory=JWST)

""")
    
    header    = '| field        | RA,Dec             | Note   | Date       '
    separator = '| :----------: | :----------------: | :----: | ----------:'
    for f in filters:
        header += f"| {f.split('-')[0]}  "
        separator += '|-------:'

    header += '|'
    separator += '|'
    print(header + '\n' + separator)

    fp.write(header + '\n' + separator + '\n')
    
    # prefix = [a.split('_')[0] for a in full['assoc']]
    # fields = utils.Unique(prefix, verbose=False)
    fields = utils.Unique(full['parent'], verbose=False)

    for fi in fields.values:
        fx = fields[fi]
        mjd = full['expstart'][fx].mean()
        iso = astropy.time.Time(mjd, format='mjd').iso.split()[0]

        row = f"| [{fi}](https://s3.amazonaws.com/grizli-panoramic/mosaics/v6.0/{fi}/index.html) "
        
        ra_map = full['crval1'][fx].mean()
        dec_map = full['crval2'][fx].mean()

        note_text = ''

        if fi == 'j224604m0518':
            MAPURL = "https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-j224612m0527/index.html?coord=341.517,-5.302"
            
        elif fi == 'j224616m0531':
            MAPURL = "https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-j224612m0527/index.html?coord=341.565,-5.520"
            
        elif fi == 'j141932p5254':
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/egs-v2/index.html?coord={ra_map:.3f},{dec_map:.3f}"
            note_text = 'EGS'
            
        elif fi.startswith('j123') & ('p62' in fi):
            # elif fi == 'j123800p6217':
            MAPURL = "https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/gdn/jwst.html?coord=189.3994832,62.2906066"
            note_text = 'GDN'
            
        elif fi in ('j033236m2755'):
            note_text = 'GDS'
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-{fi}/index.html?coord={ra_map:.3f},{dec_map:.3f}"
            
        elif fi == 'j021728m0214':
            note_text = 'XMM/UDS'
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-{fi}/index.html?coord={ra_map:.3f},{dec_map:.3f}"
            
        elif fi in ['j021824m0517','j021744m0518']:
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/uds/index.html?coord={ra_map:.3f},{dec_map:.3f}"
            note_text = 'UDS'
            
        elif fi.startswith('j0416'):
            note_text = 'MACS0416'
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-{fi}/index.html?coord={ra_map:.3f},{dec_map:.3f}"
            
        elif fi in ['j024000m0142']:
            note_text = 'Abell370'
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-{fi}/index.html?coord={ra_map:.3f},{dec_map:.3f}"
            
        else:
            MAPURL = f"https://s3.amazonaws.com/grizli-v2/ClusterTiles/Map/panoramic-{fi}/index.html?coord={ra_map:.3f},{dec_map:.3f}"
        
        row += f"| [{ra_map:8.3f}, {dec_map:8.3f}]({MAPURL}) | {note_text} | {iso} "

        for f in filters:
            nf = 8 if f < 'F250' else 2
            fx = fields[fi] & (full['filter'] == f)
            if fx.sum() > 0:
                row += f"| {full['exptime'][fx].sum()//nf/1000.:5.1f}  "
            else:
                row += f'| {" ":>5}  '


        row += '|'
        print(row)
        fp.write(row+'\n')
# Out:
# | field        | RA,Dec             | Note   | Date       | F115W  | F150W  | F200W  | F277W  | F356W  | F410M  | F444W  |
# | :----------: | :----------------: | :----: | ----------:|-------:|-------:|-------:|-------:|-------:|-------:|-------:|
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 45
#      41 iso = astropy.time.Time(mjd, format='mjd').iso.split()[0]
#      43 row = f"| [{fi}](https://s3.amazonaws.com/grizli-panoramic/mosaics/v6.0/{fi}/index.html) "
# ---> 45 ra_map = full['crval1'][fx].mean()
#      46 dec_map = full['crval2'][fx].mean()
#      48 note_text = ''
#
# File ~/miniconda3/envs/py310jw/lib/python3.10/site-packages/astropy/table/table.py:2055, in Table.__getitem__(self, item)
#    2053 def __getitem__(self, item):
#    2054     if isinstance(item, str):
# -> 2055         return self.columns[item]
#    2056     elif isinstance(item, (int, np.integer)):
#    2057         return self.Row(self, item)
#
# File ~/miniconda3/envs/py310jw/lib/python3.10/site-packages/astropy/table/table.py:264, in TableColumns.__getitem__(self, item)
#     253 """Get items from a TableColumns object.
#     254
#     255 ::
#    (...)
#     261   tc[1:3] # <TableColumns names=('b', 'c')>
#     262 """
#     263 if isinstance(item, str):
# --> 264     return OrderedDict.__getitem__(self, item)
#     265 elif isinstance(item, (int, np.integer)):
#     266     return list(self.values())[item]
#
# KeyError: 'crval1'

# %% [markdown]
# ## Cleanup

# %%
! rm panoramic*fits* panoramic*fp.png panoramic*wcs.csv panoramic*rgb.png
# Out:
# rm: cannot remove 'panoramic*rgb.png': No such file or directory

# %% [markdown]
# # Generate drizzled cutout thumbnails on AWS Lambda
#
# The cutout server uses pre-drizzled thumbnails generated on an all sky grid.  The code below runs the thumbnail generation for the little tile images that need to be generated.
#
# For example:
#
# http://grizli-cutout.herokuapp.com/thumb?all_filters=True&size=4&scl=1&asinh=True&filters=f814w,f115w-clear,f150w-clear,f200w-clear,f277w-clear,f335w-clear,f356w-clear,f410m-clear,f444w-clear&rgb_scl=1.5,0.74,1.3&pl=2&ra=53.1951458&dec=-27.7537779

# %%
import time
import os
import numpy as np
import matplotlib.pyplot as plt

import mastquery

from grizli.aws.tile_mosaic import (drizzle_tile_subregion, reset_locked,
                    get_lambda_client, send_event_lambda, count_locked, tile_subregion_wcs)

from grizli.aws import db
from grizli import utils

client = get_lambda_client()
progs = ''
nt0 = 0

# cutout tiles that need to be drizzled
tiles = db.SQL(f"""SELECT tile, subx, suby, filter, count(filter) as count,
            min(substr(e.file,1,7)) as file0, max(substr(e.file,1,7)) as file1
            FROM mosaic_tiles_exposures t, exposure_files e
            WHERE t.expid = e.eid AND in_mosaic = 0
            {progs}
            AND filter < 'G0'
            GROUP BY tile, subx, suby, filter
            ORDER BY filter ASC
            """)

timeout = 60

len(tiles)
# Out:
# 0

# %%
# Send to lambda
nt1 = len(tiles)
print(nt1, nt0-nt1)

NMAX = len(tiles)

istart = i = -1

max_locked = 800

step = max_locked - count_locked()[0]

while i < NMAX-1:
    i+=1 
    # if tiles['tile'][i] == 1183:
    #     continue
    
    if i-istart == step:
        istart = i
        print(f'\n ############### \n {time.ctime()}: Pause for {timeout} s  / {step} run previously')
        time.sleep(timeout)
        
        step = np.maximum(max_locked - count_locked()[0], 1)
        print(f'{time.ctime()}: Run {step} more \n ############## \n')
                
    event = dict(tile=int(tiles['tile'][i]), 
                    subx=int(tiles['subx'][i]),
                    suby=int(tiles['suby'][i]),
                    filter=tiles['filter'][i], 
                    exposure_count=int(tiles['count'][i]),
                    counter=i+2, 
                    time=time.ctime())
    
    if 1:
        send_event_lambda(event, client=client, func='grizli-redshift-fit')
# Out:
# 700 -700
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 2, 'time': 'Sat Sep  9 21:01:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 3, 'time': 'Sat Sep  9 21:01:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 172, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 4, 'time': 'Sat Sep  9 21:01:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 5, 'time': 'Sat Sep  9 21:01:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 6, 'time': 'Sat Sep  9 21:01:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 7, 'time': 'Sat Sep  9 21:01:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 8, 'time': 'Sat Sep  9 21:01:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 9, 'time': 'Sat Sep  9 21:01:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 178, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 10, 'time': 'Sat Sep  9 21:01:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 172, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 11, 'time': 'Sat Sep  9 21:01:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 12, 'time': 'Sat Sep  9 21:01:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 13, 'time': 'Sat Sep  9 21:01:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 14, 'time': 'Sat Sep  9 21:01:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 15, 'time': 'Sat Sep  9 21:01:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 16, 'time': 'Sat Sep  9 21:01:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 178, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 17, 'time': 'Sat Sep  9 21:01:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 18, 'time': 'Sat Sep  9 21:01:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 19, 'time': 'Sat Sep  9 21:01:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 20, 'time': 'Sat Sep  9 21:01:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 172, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 21, 'time': 'Sat Sep  9 21:01:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 22, 'time': 'Sat Sep  9 21:01:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 23, 'time': 'Sat Sep  9 21:01:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 11, 'counter': 24, 'time': 'Sat Sep  9 21:01:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 25, 'time': 'Sat Sep  9 21:01:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 26, 'time': 'Sat Sep  9 21:01:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 178, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 27, 'time': 'Sat Sep  9 21:01:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 28, 'time': 'Sat Sep  9 21:01:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 29, 'time': 'Sat Sep  9 21:01:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 30, 'time': 'Sat Sep  9 21:01:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 182, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 31, 'time': 'Sat Sep  9 21:01:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 32, 'time': 'Sat Sep  9 21:01:30 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 184, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 33, 'time': 'Sat Sep  9 21:01:30 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 185, 'filter': 'F090W-CLEAR', 'exposure_count': 1, 'counter': 34, 'time': 'Sat Sep  9 21:01:31 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 172, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 35, 'time': 'Sat Sep  9 21:01:31 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 36, 'time': 'Sat Sep  9 21:01:32 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 6, 'counter': 37, 'time': 'Sat Sep  9 21:01:32 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 11, 'counter': 38, 'time': 'Sat Sep  9 21:01:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 39, 'time': 'Sat Sep  9 21:01:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 40, 'time': 'Sat Sep  9 21:01:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 41, 'time': 'Sat Sep  9 21:01:34 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 42, 'time': 'Sat Sep  9 21:01:34 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 6, 'counter': 43, 'time': 'Sat Sep  9 21:01:35 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 182, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 44, 'time': 'Sat Sep  9 21:01:35 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 45, 'time': 'Sat Sep  9 21:01:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 184, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 46, 'time': 'Sat Sep  9 21:01:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 185, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 47, 'time': 'Sat Sep  9 21:01:37 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 171, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 48, 'time': 'Sat Sep  9 21:01:37 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 172, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 49, 'time': 'Sat Sep  9 21:01:38 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 50, 'time': 'Sat Sep  9 21:01:38 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 51, 'time': 'Sat Sep  9 21:01:39 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 52, 'time': 'Sat Sep  9 21:01:39 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 53, 'time': 'Sat Sep  9 21:01:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 54, 'time': 'Sat Sep  9 21:01:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 178, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 55, 'time': 'Sat Sep  9 21:01:41 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 56, 'time': 'Sat Sep  9 21:01:41 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 57, 'time': 'Sat Sep  9 21:01:42 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 14, 'counter': 58, 'time': 'Sat Sep  9 21:01:42 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 182, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 59, 'time': 'Sat Sep  9 21:01:43 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 60, 'time': 'Sat Sep  9 21:01:43 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 184, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 61, 'time': 'Sat Sep  9 21:01:44 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 172, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 62, 'time': 'Sat Sep  9 21:01:44 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 173, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 63, 'time': 'Sat Sep  9 21:01:45 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 174, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 64, 'time': 'Sat Sep  9 21:01:45 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 65, 'time': 'Sat Sep  9 21:01:46 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 66, 'time': 'Sat Sep  9 21:01:46 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 67, 'time': 'Sat Sep  9 21:01:47 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 178, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 68, 'time': 'Sat Sep  9 21:01:47 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 69, 'time': 'Sat Sep  9 21:01:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 70, 'time': 'Sat Sep  9 21:01:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 71, 'time': 'Sat Sep  9 21:01:49 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 182, 'filter': 'F090W-CLEAR', 'exposure_count': 6, 'counter': 72, 'time': 'Sat Sep  9 21:01:49 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 73, 'time': 'Sat Sep  9 21:01:50 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 184, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 74, 'time': 'Sat Sep  9 21:01:50 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 175, 'filter': 'F090W-CLEAR', 'exposure_count': 1, 'counter': 75, 'time': 'Sat Sep  9 21:01:51 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 176, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 76, 'time': 'Sat Sep  9 21:01:51 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 177, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 77, 'time': 'Sat Sep  9 21:01:52 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 178, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 78, 'time': 'Sat Sep  9 21:01:52 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 79, 'time': 'Sat Sep  9 21:01:53 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 80, 'time': 'Sat Sep  9 21:01:53 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 8, 'counter': 81, 'time': 'Sat Sep  9 21:01:54 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 182, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 82, 'time': 'Sat Sep  9 21:01:54 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 83, 'time': 'Sat Sep  9 21:01:55 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 184, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 84, 'time': 'Sat Sep  9 21:01:55 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 179, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 85, 'time': 'Sat Sep  9 21:01:56 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 180, 'filter': 'F090W-CLEAR', 'exposure_count': 5, 'counter': 86, 'time': 'Sat Sep  9 21:01:56 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 181, 'filter': 'F090W-CLEAR', 'exposure_count': 6, 'counter': 87, 'time': 'Sat Sep  9 21:01:57 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 182, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 88, 'time': 'Sat Sep  9 21:01:57 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 4, 'counter': 89, 'time': 'Sat Sep  9 21:01:58 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 304, 'suby': 183, 'filter': 'F090W-CLEAR', 'exposure_count': 2, 'counter': 90, 'time': 'Sat Sep  9 21:01:58 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 91, 'time': 'Sat Sep  9 21:01:59 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 92, 'time': 'Sat Sep  9 21:01:59 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 172, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 93, 'time': 'Sat Sep  9 21:02:00 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 94, 'time': 'Sat Sep  9 21:02:00 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 95, 'time': 'Sat Sep  9 21:02:01 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 96, 'time': 'Sat Sep  9 21:02:01 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 97, 'time': 'Sat Sep  9 21:02:02 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 98, 'time': 'Sat Sep  9 21:02:02 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 178, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 99, 'time': 'Sat Sep  9 21:02:03 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 172, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 100, 'time': 'Sat Sep  9 21:02:03 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 101, 'time': 'Sat Sep  9 21:02:04 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 102, 'time': 'Sat Sep  9 21:02:04 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 103, 'time': 'Sat Sep  9 21:02:05 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 104, 'time': 'Sat Sep  9 21:02:05 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 105, 'time': 'Sat Sep  9 21:02:06 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 178, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 106, 'time': 'Sat Sep  9 21:02:06 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 107, 'time': 'Sat Sep  9 21:02:06 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 108, 'time': 'Sat Sep  9 21:02:07 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 109, 'time': 'Sat Sep  9 21:02:07 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 172, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 110, 'time': 'Sat Sep  9 21:02:08 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 111, 'time': 'Sat Sep  9 21:02:08 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 112, 'time': 'Sat Sep  9 21:02:09 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 11, 'counter': 113, 'time': 'Sat Sep  9 21:02:09 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 114, 'time': 'Sat Sep  9 21:02:10 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 115, 'time': 'Sat Sep  9 21:02:10 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 178, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 116, 'time': 'Sat Sep  9 21:02:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 117, 'time': 'Sat Sep  9 21:02:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 118, 'time': 'Sat Sep  9 21:02:12 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 119, 'time': 'Sat Sep  9 21:02:12 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 182, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 120, 'time': 'Sat Sep  9 21:02:13 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 121, 'time': 'Sat Sep  9 21:02:13 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 184, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 122, 'time': 'Sat Sep  9 21:02:14 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 185, 'filter': 'F115W-CLEAR', 'exposure_count': 1, 'counter': 123, 'time': 'Sat Sep  9 21:02:14 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 172, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 124, 'time': 'Sat Sep  9 21:02:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 125, 'time': 'Sat Sep  9 21:02:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 6, 'counter': 126, 'time': 'Sat Sep  9 21:02:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 11, 'counter': 127, 'time': 'Sat Sep  9 21:02:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 128, 'time': 'Sat Sep  9 21:02:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 129, 'time': 'Sat Sep  9 21:02:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 130, 'time': 'Sat Sep  9 21:02:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 131, 'time': 'Sat Sep  9 21:02:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 6, 'counter': 132, 'time': 'Sat Sep  9 21:02:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 182, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 133, 'time': 'Sat Sep  9 21:02:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 134, 'time': 'Sat Sep  9 21:02:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 184, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 135, 'time': 'Sat Sep  9 21:02:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 185, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 136, 'time': 'Sat Sep  9 21:02:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 171, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 137, 'time': 'Sat Sep  9 21:02:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 172, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 138, 'time': 'Sat Sep  9 21:02:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 139, 'time': 'Sat Sep  9 21:02:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 140, 'time': 'Sat Sep  9 21:02:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 141, 'time': 'Sat Sep  9 21:02:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 142, 'time': 'Sat Sep  9 21:02:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 143, 'time': 'Sat Sep  9 21:02:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 178, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 144, 'time': 'Sat Sep  9 21:02:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 145, 'time': 'Sat Sep  9 21:02:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 146, 'time': 'Sat Sep  9 21:02:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 14, 'counter': 147, 'time': 'Sat Sep  9 21:02:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 182, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 148, 'time': 'Sat Sep  9 21:02:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 149, 'time': 'Sat Sep  9 21:02:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 184, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 150, 'time': 'Sat Sep  9 21:02:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 172, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 151, 'time': 'Sat Sep  9 21:02:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 173, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 152, 'time': 'Sat Sep  9 21:02:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 174, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 153, 'time': 'Sat Sep  9 21:02:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 154, 'time': 'Sat Sep  9 21:02:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 155, 'time': 'Sat Sep  9 21:02:30 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 156, 'time': 'Sat Sep  9 21:02:30 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 178, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 157, 'time': 'Sat Sep  9 21:02:31 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 158, 'time': 'Sat Sep  9 21:02:31 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 159, 'time': 'Sat Sep  9 21:02:32 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 160, 'time': 'Sat Sep  9 21:02:32 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 182, 'filter': 'F115W-CLEAR', 'exposure_count': 6, 'counter': 161, 'time': 'Sat Sep  9 21:02:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 162, 'time': 'Sat Sep  9 21:02:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 184, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 163, 'time': 'Sat Sep  9 21:02:34 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 175, 'filter': 'F115W-CLEAR', 'exposure_count': 1, 'counter': 164, 'time': 'Sat Sep  9 21:02:34 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 176, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 165, 'time': 'Sat Sep  9 21:02:35 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 177, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 166, 'time': 'Sat Sep  9 21:02:35 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 178, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 167, 'time': 'Sat Sep  9 21:02:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 168, 'time': 'Sat Sep  9 21:02:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 169, 'time': 'Sat Sep  9 21:02:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 8, 'counter': 170, 'time': 'Sat Sep  9 21:02:37 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 182, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 171, 'time': 'Sat Sep  9 21:02:37 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 172, 'time': 'Sat Sep  9 21:02:38 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 184, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 173, 'time': 'Sat Sep  9 21:02:39 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 179, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 174, 'time': 'Sat Sep  9 21:02:39 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 180, 'filter': 'F115W-CLEAR', 'exposure_count': 5, 'counter': 175, 'time': 'Sat Sep  9 21:02:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 181, 'filter': 'F115W-CLEAR', 'exposure_count': 6, 'counter': 176, 'time': 'Sat Sep  9 21:02:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 182, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 177, 'time': 'Sat Sep  9 21:02:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 4, 'counter': 178, 'time': 'Sat Sep  9 21:02:41 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 304, 'suby': 183, 'filter': 'F115W-CLEAR', 'exposure_count': 2, 'counter': 179, 'time': 'Sat Sep  9 21:02:41 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 180, 'time': 'Sat Sep  9 21:02:42 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 181, 'time': 'Sat Sep  9 21:02:42 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 172, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 182, 'time': 'Sat Sep  9 21:02:43 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 183, 'time': 'Sat Sep  9 21:02:43 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 184, 'time': 'Sat Sep  9 21:02:44 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 185, 'time': 'Sat Sep  9 21:02:44 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 186, 'time': 'Sat Sep  9 21:02:45 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 187, 'time': 'Sat Sep  9 21:02:45 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 178, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 188, 'time': 'Sat Sep  9 21:02:46 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 172, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 189, 'time': 'Sat Sep  9 21:02:46 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 190, 'time': 'Sat Sep  9 21:02:47 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 191, 'time': 'Sat Sep  9 21:02:47 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 192, 'time': 'Sat Sep  9 21:02:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 193, 'time': 'Sat Sep  9 21:02:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 194, 'time': 'Sat Sep  9 21:02:49 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 178, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 195, 'time': 'Sat Sep  9 21:02:49 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 196, 'time': 'Sat Sep  9 21:02:50 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 197, 'time': 'Sat Sep  9 21:02:50 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 198, 'time': 'Sat Sep  9 21:02:51 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 172, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 199, 'time': 'Sat Sep  9 21:02:51 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 200, 'time': 'Sat Sep  9 21:02:52 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 201, 'time': 'Sat Sep  9 21:02:52 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 11, 'counter': 202, 'time': 'Sat Sep  9 21:02:53 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 203, 'time': 'Sat Sep  9 21:02:53 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 204, 'time': 'Sat Sep  9 21:02:54 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 178, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 205, 'time': 'Sat Sep  9 21:02:54 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 206, 'time': 'Sat Sep  9 21:02:55 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 207, 'time': 'Sat Sep  9 21:02:55 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 208, 'time': 'Sat Sep  9 21:02:55 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 182, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 209, 'time': 'Sat Sep  9 21:02:56 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 210, 'time': 'Sat Sep  9 21:02:56 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 184, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 211, 'time': 'Sat Sep  9 21:02:57 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 185, 'filter': 'F150W-CLEAR', 'exposure_count': 1, 'counter': 212, 'time': 'Sat Sep  9 21:02:57 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 172, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 213, 'time': 'Sat Sep  9 21:02:58 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 214, 'time': 'Sat Sep  9 21:02:58 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 6, 'counter': 215, 'time': 'Sat Sep  9 21:02:59 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 11, 'counter': 216, 'time': 'Sat Sep  9 21:02:59 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 217, 'time': 'Sat Sep  9 21:03:00 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 218, 'time': 'Sat Sep  9 21:03:00 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 219, 'time': 'Sat Sep  9 21:03:01 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 220, 'time': 'Sat Sep  9 21:03:01 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 6, 'counter': 221, 'time': 'Sat Sep  9 21:03:02 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 182, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 222, 'time': 'Sat Sep  9 21:03:02 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 223, 'time': 'Sat Sep  9 21:03:03 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 184, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 224, 'time': 'Sat Sep  9 21:03:03 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 185, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 225, 'time': 'Sat Sep  9 21:03:04 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 171, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 226, 'time': 'Sat Sep  9 21:03:04 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 172, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 227, 'time': 'Sat Sep  9 21:03:04 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 228, 'time': 'Sat Sep  9 21:03:05 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 229, 'time': 'Sat Sep  9 21:03:05 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 230, 'time': 'Sat Sep  9 21:03:06 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 231, 'time': 'Sat Sep  9 21:03:06 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 232, 'time': 'Sat Sep  9 21:03:07 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 178, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 233, 'time': 'Sat Sep  9 21:03:07 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 234, 'time': 'Sat Sep  9 21:03:08 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 235, 'time': 'Sat Sep  9 21:03:08 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 14, 'counter': 236, 'time': 'Sat Sep  9 21:03:09 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 182, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 237, 'time': 'Sat Sep  9 21:03:09 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 238, 'time': 'Sat Sep  9 21:03:10 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 184, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 239, 'time': 'Sat Sep  9 21:03:10 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 172, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 240, 'time': 'Sat Sep  9 21:03:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 173, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 241, 'time': 'Sat Sep  9 21:03:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 174, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 242, 'time': 'Sat Sep  9 21:03:12 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 243, 'time': 'Sat Sep  9 21:03:12 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 244, 'time': 'Sat Sep  9 21:03:13 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 245, 'time': 'Sat Sep  9 21:03:13 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 178, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 246, 'time': 'Sat Sep  9 21:03:14 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 247, 'time': 'Sat Sep  9 21:03:14 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 248, 'time': 'Sat Sep  9 21:03:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 249, 'time': 'Sat Sep  9 21:03:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 182, 'filter': 'F150W-CLEAR', 'exposure_count': 6, 'counter': 250, 'time': 'Sat Sep  9 21:03:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 251, 'time': 'Sat Sep  9 21:03:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 184, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 252, 'time': 'Sat Sep  9 21:03:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 175, 'filter': 'F150W-CLEAR', 'exposure_count': 1, 'counter': 253, 'time': 'Sat Sep  9 21:03:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 176, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 254, 'time': 'Sat Sep  9 21:03:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 177, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 255, 'time': 'Sat Sep  9 21:03:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 178, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 256, 'time': 'Sat Sep  9 21:03:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 257, 'time': 'Sat Sep  9 21:03:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 258, 'time': 'Sat Sep  9 21:03:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 8, 'counter': 259, 'time': 'Sat Sep  9 21:03:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 182, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 260, 'time': 'Sat Sep  9 21:03:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 261, 'time': 'Sat Sep  9 21:03:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 184, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 262, 'time': 'Sat Sep  9 21:03:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 179, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 263, 'time': 'Sat Sep  9 21:03:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 180, 'filter': 'F150W-CLEAR', 'exposure_count': 5, 'counter': 264, 'time': 'Sat Sep  9 21:03:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 181, 'filter': 'F150W-CLEAR', 'exposure_count': 6, 'counter': 265, 'time': 'Sat Sep  9 21:03:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 182, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 266, 'time': 'Sat Sep  9 21:03:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 4, 'counter': 267, 'time': 'Sat Sep  9 21:03:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 304, 'suby': 183, 'filter': 'F150W-CLEAR', 'exposure_count': 2, 'counter': 268, 'time': 'Sat Sep  9 21:03:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 173, 'filter': 'F200W-CLEAR', 'exposure_count': 4, 'counter': 269, 'time': 'Sat Sep  9 21:03:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 174, 'filter': 'F200W-CLEAR', 'exposure_count': 2, 'counter': 270, 'time': 'Sat Sep  9 21:03:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 172, 'filter': 'F200W-CLEAR', 'exposure_count': 2, 'counter': 271, 'time': 'Sat Sep  9 21:03:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 173, 'filter': 'F200W-CLEAR', 'exposure_count': 4, 'counter': 272, 'time': 'Sat Sep  9 21:03:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 174, 'filter': 'F200W-CLEAR', 'exposure_count': 4, 'counter': 273, 'time': 'Sat Sep  9 21:03:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 175, 'filter': 'F200W-CLEAR', 'exposure_count': 8, 'counter': 274, 'time': 'Sat Sep  9 21:03:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 176, 'filter': 'F200W-CLEAR', 'exposure_count': 4, 'counter': 275, 'time': 'Sat Sep  9 21:03:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 177, 'filter': 'F200W-CLEAR', 'exposure_count': 4, 'counter': 276, 'time': 'Sat Sep  9 21:03:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 178, 'filter': 'F200W-CLEAR', 'exposure_count': 2, 'counter': 277, 'time': 'Sat Sep  9 21:03:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 172, 'filter': 'F200W-CLEAR', 'exposure_count': 4, 'counter': 278, 'time': 'Sat Sep  9 21:03:29 2023'}
# ...
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 179, 'filter': 'F410M-CLEAR', 'exposure_count': 2, 'counter': 610, 'time': 'Sat Sep  9 21:06:09 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 180, 'filter': 'F410M-CLEAR', 'exposure_count': 4, 'counter': 611, 'time': 'Sat Sep  9 21:06:10 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 181, 'filter': 'F410M-CLEAR', 'exposure_count': 4, 'counter': 612, 'time': 'Sat Sep  9 21:06:10 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 182, 'filter': 'F410M-CLEAR', 'exposure_count': 4, 'counter': 613, 'time': 'Sat Sep  9 21:06:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 183, 'filter': 'F410M-CLEAR', 'exposure_count': 4, 'counter': 614, 'time': 'Sat Sep  9 21:06:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 304, 'suby': 183, 'filter': 'F410M-CLEAR', 'exposure_count': 1, 'counter': 615, 'time': 'Sat Sep  9 21:06:11 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 616, 'time': 'Sat Sep  9 21:06:12 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 295, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 617, 'time': 'Sat Sep  9 21:06:12 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 172, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 618, 'time': 'Sat Sep  9 21:06:13 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 619, 'time': 'Sat Sep  9 21:06:13 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 620, 'time': 'Sat Sep  9 21:06:14 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 175, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 621, 'time': 'Sat Sep  9 21:06:14 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 622, 'time': 'Sat Sep  9 21:06:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 296, 'suby': 177, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 623, 'time': 'Sat Sep  9 21:06:15 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 172, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 624, 'time': 'Sat Sep  9 21:06:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 625, 'time': 'Sat Sep  9 21:06:16 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 626, 'time': 'Sat Sep  9 21:06:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 175, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 627, 'time': 'Sat Sep  9 21:06:17 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 628, 'time': 'Sat Sep  9 21:06:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 177, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 629, 'time': 'Sat Sep  9 21:06:18 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 178, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 630, 'time': 'Sat Sep  9 21:06:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 631, 'time': 'Sat Sep  9 21:06:19 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 632, 'time': 'Sat Sep  9 21:06:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 297, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 633, 'time': 'Sat Sep  9 21:06:20 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 172, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 634, 'time': 'Sat Sep  9 21:06:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 635, 'time': 'Sat Sep  9 21:06:21 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 636, 'time': 'Sat Sep  9 21:06:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 175, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 637, 'time': 'Sat Sep  9 21:06:22 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 638, 'time': 'Sat Sep  9 21:06:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 177, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 639, 'time': 'Sat Sep  9 21:06:23 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 178, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 640, 'time': 'Sat Sep  9 21:06:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 641, 'time': 'Sat Sep  9 21:06:24 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 642, 'time': 'Sat Sep  9 21:06:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 643, 'time': 'Sat Sep  9 21:06:25 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 182, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 644, 'time': 'Sat Sep  9 21:06:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 645, 'time': 'Sat Sep  9 21:06:26 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 184, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 646, 'time': 'Sat Sep  9 21:06:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 298, 'suby': 185, 'filter': 'F444W-CLEAR', 'exposure_count': 1, 'counter': 647, 'time': 'Sat Sep  9 21:06:27 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 172, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 648, 'time': 'Sat Sep  9 21:06:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 649, 'time': 'Sat Sep  9 21:06:28 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 650, 'time': 'Sat Sep  9 21:06:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 175, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 651, 'time': 'Sat Sep  9 21:06:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 652, 'time': 'Sat Sep  9 21:06:29 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 177, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 653, 'time': 'Sat Sep  9 21:06:30 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 654, 'time': 'Sat Sep  9 21:06:30 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 655, 'time': 'Sat Sep  9 21:06:31 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 656, 'time': 'Sat Sep  9 21:06:31 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 182, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 657, 'time': 'Sat Sep  9 21:06:32 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 658, 'time': 'Sat Sep  9 21:06:32 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 184, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 659, 'time': 'Sat Sep  9 21:06:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 299, 'suby': 185, 'filter': 'F444W-CLEAR', 'exposure_count': 1, 'counter': 660, 'time': 'Sat Sep  9 21:06:33 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 171, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 661, 'time': 'Sat Sep  9 21:06:34 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 172, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 662, 'time': 'Sat Sep  9 21:06:34 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 663, 'time': 'Sat Sep  9 21:06:35 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 664, 'time': 'Sat Sep  9 21:06:35 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 175, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 665, 'time': 'Sat Sep  9 21:06:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 666, 'time': 'Sat Sep  9 21:06:36 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 177, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 667, 'time': 'Sat Sep  9 21:06:37 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 178, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 668, 'time': 'Sat Sep  9 21:06:37 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 669, 'time': 'Sat Sep  9 21:06:38 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 670, 'time': 'Sat Sep  9 21:06:38 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 671, 'time': 'Sat Sep  9 21:06:39 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 182, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 672, 'time': 'Sat Sep  9 21:06:39 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 673, 'time': 'Sat Sep  9 21:06:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 300, 'suby': 184, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 674, 'time': 'Sat Sep  9 21:06:40 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 172, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 675, 'time': 'Sat Sep  9 21:06:41 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 173, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 676, 'time': 'Sat Sep  9 21:06:41 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 174, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 677, 'time': 'Sat Sep  9 21:06:42 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 175, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 678, 'time': 'Sat Sep  9 21:06:42 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 679, 'time': 'Sat Sep  9 21:06:43 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 177, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 680, 'time': 'Sat Sep  9 21:06:43 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 178, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 681, 'time': 'Sat Sep  9 21:06:44 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 682, 'time': 'Sat Sep  9 21:06:44 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 683, 'time': 'Sat Sep  9 21:06:45 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 684, 'time': 'Sat Sep  9 21:06:45 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 182, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 685, 'time': 'Sat Sep  9 21:06:46 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 686, 'time': 'Sat Sep  9 21:06:46 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 301, 'suby': 184, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 687, 'time': 'Sat Sep  9 21:06:47 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 176, 'filter': 'F444W-CLEAR', 'exposure_count': 3, 'counter': 688, 'time': 'Sat Sep  9 21:06:47 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 178, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 689, 'time': 'Sat Sep  9 21:06:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 690, 'time': 'Sat Sep  9 21:06:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 691, 'time': 'Sat Sep  9 21:06:48 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 692, 'time': 'Sat Sep  9 21:06:49 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 182, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 693, 'time': 'Sat Sep  9 21:06:49 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 694, 'time': 'Sat Sep  9 21:06:50 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 302, 'suby': 184, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 695, 'time': 'Sat Sep  9 21:06:50 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 179, 'filter': 'F444W-CLEAR', 'exposure_count': 2, 'counter': 696, 'time': 'Sat Sep  9 21:06:51 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 180, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 697, 'time': 'Sat Sep  9 21:06:51 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 181, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 698, 'time': 'Sat Sep  9 21:06:52 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 182, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 699, 'time': 'Sat Sep  9 21:06:52 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 303, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 4, 'counter': 700, 'time': 'Sat Sep  9 21:06:53 2023'}
# Send event to grizli-redshift-fit: {'tile': 217, 'subx': 304, 'suby': 183, 'filter': 'F444W-CLEAR', 'exposure_count': 1, 'counter': 701, 'time': 'Sat Sep  9 21:06:53 2023'}

# %% [markdown]
# # Mosaic FITSMap tiling on S3
#
# Define field tiles for the interactive FitsMap webpages

# %%
tile_fields = db.SQL("""select field, AVG(crval1) as ra, AVG(crval2) as dec, count(field) from combined_tiles
group by field
order by field
""")
tile_fields
# Out:
# <GTable length=53>
#         field               ra          dec      count
#         str22            float64      float64    int64
# ---------------------- ------------ ------------ -----
#              abell2744   3.58750000 -30.39666670   225
#               abell370  39.97500000  -1.57527780   225
#                    cos 150.12500000   2.20000000  1089
#                dracoii 238.19833330  64.56528000    64
#                    egs 214.82880000  52.80673330   484
#                 egs-v2 214.82880000  52.80673330   484
#                    gdn 189.23690290  62.23128390   289
#                    gds  53.15924640 -27.78282230   289
#           j010256m4914  15.69609258 -49.26215000   289
#                    ...          ...          ...   ...
# panoramic-j144904m1017 222.24498208 -10.30890000   289
# panoramic-j145652p2444 224.19531288  24.71440000   289
# panoramic-j150604p5409 226.47078395  54.12920000   289
# panoramic-j153500p2325 233.71460162  23.39440000   289
# panoramic-j170720p5853 256.79196841  58.85375000   289
# panoramic-j224612m0527 341.51328554  -5.43355500   289
# panoramic-j234512m4235 356.26972722 -42.61620000   289
#               sgas1723 260.89500000  34.20500000    64
#                    uds  34.40869000  -5.16299000   484

# %%
field_footprints = db.SQL("""select field, tile, footprint from combined_tiles""")
len(field_footprints)
# Out:
# 15932

# %%
fields = utils.read_catalog('panoramic_fields.txt')
fields['parent'] = fields['field']
fields['field'] = [f'panoramic-{f}' for f in fields['field']]

so = np.argsort(fields['date'])

# Shift by half tile to put one NIRCam module in the center of a tile
xsh = 3.072/60./2.

fields['ra'] -= xsh/np.cos(fields['dec']/180*np.pi)
fields['dec'] -= xsh

fields[so]
# Out:
# <GTable length=36>
#         field            n      sx      sy           ra                 dec           nx    ny     date        time        parent
#         str22          int64 float64 float64      float64             float64       int64 int64   str10       str12        str12
# ---------------------- ----- ------- ------- ------------------ ------------------- ----- ----- ---------- ------------ ------------
# panoramic-j170720p5853   120     4.9     6.9  256.7919684123834  58.853750000000005     4     6 2023-02-18 00:03:56.209 j170720p5853
# panoramic-j153500p2325   240     3.6     6.4 233.71460161799536             23.3944     3     5 2023-03-06 09:39:23.999 j153500p2325
# panoramic-j145652p2444    40     5.3     6.7 224.19531287984384  24.714399999999998     4     5 2023-03-24 02:33:18.312 j145652p2444
# panoramic-j123816p6217     9     6.3     3.7 189.51496695096552            62.25285     5     3 2023-03-26 02:37:57.468 j123816p6217
# panoramic-j123800p6217   432    17.0    15.7 189.43051999110227  62.223800000000004    13    12 2023-03-28 07:25:57.468 j123800p6217
# panoramic-j125652p5652   240     6.4     3.8  194.1646653081678             56.8401     5     3 2023-04-01 19:15:23.999 j125652p5652
# panoramic-j150604p5409   160     6.5     7.1 226.47078395384054  54.129200000000004     5     6 2023-04-03 14:28:49.893 j150604p5409
# panoramic-j090000p0207    80     4.0     6.5 134.97838256387973             2.08847     3     5 2023-04-03 09:42:05.050 j090000p0207
# panoramic-j093452p6116    80     5.9     6.5 143.65523834493206             61.2468     5     5 2023-04-06 19:16:17.682 j093452p6116
#                    ...   ...     ...     ...                ...                 ...   ...   ...        ...          ...          ...
# panoramic-j021728m0214   240     4.7     6.7 34.337380628624736           -2.253835     4     5 2023-08-06 21:43:52.418 j021728m0214
# panoramic-j013444m1532   120     4.0     6.6 23.660529782879134            -15.5568     3     5 2023-08-14 00:03:56.209 j013444m1532
# panoramic-j010500p0217   200     5.2     7.0 16.219429673166186  2.2568900000000003     4     6 2023-08-18 02:50:29.040 j010500p0217
# panoramic-j021744m0518   280    15.0    12.2  34.38448972947805            -5.33407    11     9 2023-08-20 09:49:57.468 j021744m0518
# panoramic-j013900m1019   172     4.9     7.9 24.717079047716165 -10.345600000000001     4     6 2023-08-23 09:52:27.783 j013900m1019
# panoramic-j041616m2409   330     6.9     9.0  64.05824142767705           -24.18965     6     7 2023-08-27 05:14:29.040 j041616m2409
# panoramic-j014428p1715   180     5.5     7.8  26.08164564946814  17.214949999999998     5     6 2023-08-29 19:27:44.836 j014428p1715
# panoramic-j033236m2755   142     3.6     6.3  53.12782977735651            -27.9378     3     5 2023-09-03 06:19:37.230 j033236m2755
# panoramic-j024000m0142    90     3.8     6.9 39.981638837697865            -1.71727     3     6 2023-09-05 05:02:40.415 j024000m0142

# %%
# Look if panoramic fields already have tiles
coo = np.array([fields['ra'], fields['dec']]).T

fields['field'] = [f'panoramic-{f}' for f in fields['parent']]
# fields['field'] = [f'{f}' for f in fields['parent']]

fields['in_tile'] = False
for fi, fp in zip(field_footprints['field'], field_footprints['footprint']):
    sr = utils.SRegion(fp)
    in_i = sr.path[0].contains_points(coo)
    if in_i.sum() > 0:
        fields['field'][in_i] = fi
        fields['in_tile'] |= in_i
    
# Default 46 arcmin on a size to be big and to match
# center tile default of (9,9) in grizli.field_tiles.process_tile
fields['dx'] = fields['dy'] = 46
fields['rsize'] = fields['dx']/2

# %%
fields[so]
# Out:
# <GTable length=36>
#         field            n      sx      sy           ra                 dec           nx    ny     date        time        parent    in_tile   dx    dy   rsize
#         str22          int64 float64 float64      float64             float64       int64 int64   str10       str12        str12       bool  int64 int64 float64
# ---------------------- ----- ------- ------- ------------------ ------------------- ----- ----- ---------- ------------ ------------ ------- ----- ----- -------
# panoramic-j170720p5853   120     4.9     6.9  256.7919684123834  58.853750000000005     4     6 2023-02-18 00:03:56.209 j170720p5853    True    46    46    23.0
# panoramic-j153500p2325   240     3.6     6.4 233.71460161799536             23.3944     3     5 2023-03-06 09:39:23.999 j153500p2325    True    46    46    23.0
# panoramic-j145652p2444    40     5.3     6.7 224.19531287984384  24.714399999999998     4     5 2023-03-24 02:33:18.312 j145652p2444    True    46    46    23.0
#                    gdn     9     6.3     3.7 189.51496695096552            62.25285     5     3 2023-03-26 02:37:57.468 j123816p6217    True    46    46    23.0
#                    gdn   432    17.0    15.7 189.43051999110227  62.223800000000004    13    12 2023-03-28 07:25:57.468 j123800p6217    True    46    46    23.0
# panoramic-j125652p5652   240     6.4     3.8  194.1646653081678             56.8401     5     3 2023-04-01 19:15:23.999 j125652p5652    True    46    46    23.0
# panoramic-j150604p5409   160     6.5     7.1 226.47078395384054  54.129200000000004     5     6 2023-04-03 14:28:49.893 j150604p5409    True    46    46    23.0
# panoramic-j090000p0207    80     4.0     6.5 134.97838256387973             2.08847     3     5 2023-04-03 09:42:05.050 j090000p0207    True    46    46    23.0
# panoramic-j093452p6116    80     5.9     6.5 143.65523834493206             61.2468     5     5 2023-04-06 19:16:17.682 j093452p6116    True    46    46    23.0
#                    ...   ...     ...     ...                ...                 ...   ...   ...        ...          ...          ...     ...   ...   ...     ...
# panoramic-j021728m0214   240     4.7     6.7 34.337380628624736           -2.253835     4     5 2023-08-06 21:43:52.418 j021728m0214    True    46    46    23.0
# panoramic-j013444m1532   120     4.0     6.6 23.660529782879134            -15.5568     3     5 2023-08-14 00:03:56.209 j013444m1532    True    46    46    23.0
# panoramic-j010500p0217   200     5.2     7.0 16.219429673166186  2.2568900000000003     4     6 2023-08-18 02:50:29.040 j010500p0217    True    46    46    23.0
#                    uds   280    15.0    12.2  34.38448972947805            -5.33407    11     9 2023-08-20 09:49:57.468 j021744m0518    True    46    46    23.0
# panoramic-j013900m1019   172     4.9     7.9 24.717079047716165 -10.345600000000001     4     6 2023-08-23 09:52:27.783 j013900m1019    True    46    46    23.0
#               macs0416   330     6.9     9.0  64.05824142767705           -24.18965     6     7 2023-08-27 05:14:29.040 j041616m2409    True    46    46    23.0
# panoramic-j014428p1715   180     5.5     7.8  26.08164564946814  17.214949999999998     5     6 2023-08-29 19:27:44.836 j014428p1715    True    46    46    23.0
#                    gds   142     3.6     6.3  53.12782977735651            -27.9378     3     5 2023-09-03 06:19:37.230 j033236m2755    True    46    46    23.0
#               abell370    90     3.8     6.9 39.981638837697865            -1.71727     3     6 2023-09-05 05:02:40.415 j024000m0142    True    46    46    23.0

# %%
from grizli.aws.field_tiles import make_field_tiles

ix = so[-1]
tiles = make_field_tiles(**fields[ix], tile_npix=2048+256, pscale=0.08, initial_status=90, send_to_database=False)

# CRPIX1, CRPIX2 should be 1152,1152 for tile '09.09'
ii = tiles['tile'] == '09.09'
tiles[ii]
# Out:
# abell370: tile size, arcmin = 3.072
# <GTable length=1>
#  tile wcsaxes  crpix1  crpix2        cd1_1         ... naxis1 naxis2                                         footprint                                         status  field
#  str5  int64  float64 float64       float64        ... int64  int64                                            str89                                           int64    str8
# ----- ------- ------- ------- -------------------- ... ------ ------ ----------------------------------------------------------------------------------------- ------ --------
# 09.09       2  1152.0  1152.0 -2.2222222222222e-05 ...   2304   2304 ((40.007240,-1.742859),(40.007239,-1.691681),(39.956039,-1.691681),(39.956038,-1.742859))     90 abell370

# %% [markdown]
# # Send to database

# %%
# if 0:
#     db.execute("delete from combined_tiles where field like 'panoramic%%'")

# %%
SEND_TO_DB = False

for ix in so: #range(len(fields)):
    if not fields['in_tile'][ix]:
        print(ix, fields[ix]['field'])
        if SEND_TO_DB:
            tiles = make_field_tiles(**fields[ix], tile_npix=2048+256, pscale=0.08,
                                 initial_status=90, send_to_database=True)
        else:
            print('Set SEND_TO_DB = True to send the new tile defs to the database')
            
    else:
        print(f"{ix:>3}: Tile field {fields['field'][ix]} found")
# Out:
#  32: Tile field panoramic-j170720p5853 found
#  31: Tile field panoramic-j153500p2325 found
#  29: Tile field panoramic-j145652p2444 found
#  21: Tile field gdn found
#  20: Tile field gdn found
#  22: Tile field panoramic-j125652p5652 found
#  30: Tile field panoramic-j150604p5409 found
#  13: Tile field panoramic-j090000p0207 found
#  15: Tile field panoramic-j093452p6116 found
#  16: Tile field panoramic-j094232p0923 found
#  14: Tile field panoramic-j093144p0819 found
#  17: Tile field panoramic-j100736p2109 found
#  25: Tile field panoramic-j134348p5549 found
#  24: Tile field panoramic-j131432p2432 found
#  18: Tile field panoramic-j121932p0330 found
#  27: Tile field panoramic-j142536p5630 found
#  23: Tile field panoramic-j130016p1215 found
#  26: Tile field egs found
#  28: Tile field panoramic-j144904m1017 found
#  19: Tile field panoramic-j123140m1618 found
#   0: Tile field panoramic-j000352m1120 found
#  34: Tile field panoramic-j224612m0527 found
#  33: Tile field panoramic-j224612m0527 found
#   8: Tile field uds found
#  12: Tile field panoramic-j043844m6849 found
#  35: Tile field panoramic-j234512m4235 found
#   1: Tile field panoramic-j010408m5508 found
#   6: Tile field panoramic-j021728m0214 found
#   3: Tile field panoramic-j013444m1532 found
#   2: Tile field panoramic-j010500p0217 found
#   7: Tile field uds found
#   4: Tile field panoramic-j013900m1019 found
#  11: Tile field macs0416 found
#   5: Tile field panoramic-j014428p1715 found
#  10: Tile field gds found
#   9: Tile field abell370 found

# %% [markdown]
# # Generate drizzled tiles on EC2
#
# **Update (13 Jun 2023):** Do this in `Notebooks/step4-make-map-tiles.ipynb`
